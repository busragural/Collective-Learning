# %% [markdown]
# # RETRIEVAL ENSEMBLE
#
# Dataset: https://huggingface.co/datasets/merve/turkish_instructions

# %% [markdown]
# ## PREPROCESSING

# %%
from datasets import load_dataset

ds = load_dataset("merve/turkish_instructions")
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'talimat', ' giriş', ' çıktı'],
#         num_rows: 51563
#     })
# })

# %%
import pandas as pd 
df = pd.DataFrame(ds['train'])
df.head()
# Out:
#    Unnamed: 0                                            talimat  giriş  \
# 0           0   Aşağıdaki bağlamda orijinal bir şey söyleyin:...   None
# 1           1   Aşağıdaki makale için bir başlık önerin: Bu m...   None
# 2           2   Şu konuyla ilgili 5 anahtar kelimeden oluşan ...   None
# 3           3   Bu cümleyi pasiften aktife değiştirin: Yeni p...   None
# 4           4  Aşağıdaki fenomeni tanımlayan üç bilimsel teri...   None
#
#                                                çıktı
# 0   Ekibe katkıda bulunmaya başlamak ve bu alanda...
# 1   "Dijital İletişimin Gücü: İnternet İş Ortamın...
# 2   1. Karbon emisyonları 2. Yenilenebilir enerji...
# 3         Belediye başkanı yeni politikayı açıkladı.
# 4   Yerçekimi kuvveti, Newton'un evrensel çekim y...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51563 entries, 0 to 51562
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  51563 non-null  int64
#  1   talimat     51563 non-null  object
#  2    giriş      19088 non-null  object
#  3    çıktı      51563 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.6+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'talimat', ' giriş', ' çıktı'], dtype='object')

# %%
#The 'giriş' is combined with the 'talimat'.
df['talimat'] = df.apply(lambda x: x['talimat'] + str(x[' giriş']) if pd.notnull(x[' giriş']) else x['talimat'], axis=1)
df.head()
# Out:
#    Unnamed: 0                                            talimat  giriş  \
# 0           0   Aşağıdaki bağlamda orijinal bir şey söyleyin:...   None
# 1           1   Aşağıdaki makale için bir başlık önerin: Bu m...   None
# 2           2   Şu konuyla ilgili 5 anahtar kelimeden oluşan ...   None
# 3           3   Bu cümleyi pasiften aktife değiştirin: Yeni p...   None
# 4           4  Aşağıdaki fenomeni tanımlayan üç bilimsel teri...   None
#
#                                                çıktı
# 0   Ekibe katkıda bulunmaya başlamak ve bu alanda...
# 1   "Dijital İletişimin Gücü: İnternet İş Ortamın...
# 2   1. Karbon emisyonları 2. Yenilenebilir enerji...
# 3         Belediye başkanı yeni politikayı açıkladı.
# 4   Yerçekimi kuvveti, Newton'un evrensel çekim y...

# %%
df.iloc[11]['talimat']
# Out:
# ' Listeden herhangi üç kelime seçin. elma, muz, portakal'

# %%
df = df.drop(columns=['Unnamed: 0', ' giriş'], axis=1)
df.head()
# Out:
#                                              talimat  \
# 0   Aşağıdaki bağlamda orijinal bir şey söyleyin:...
# 1   Aşağıdaki makale için bir başlık önerin: Bu m...
# 2   Şu konuyla ilgili 5 anahtar kelimeden oluşan ...
# 3   Bu cümleyi pasiften aktife değiştirin: Yeni p...
# 4  Aşağıdaki fenomeni tanımlayan üç bilimsel teri...
#
#                                                çıktı
# 0   Ekibe katkıda bulunmaya başlamak ve bu alanda...
# 1   "Dijital İletişimin Gücü: İnternet İş Ortamın...
# 2   1. Karbon emisyonları 2. Yenilenebilir enerji...
# 3         Belediye başkanı yeni politikayı açıkladı.
# 4   Yerçekimi kuvveti, Newton'un evrensel çekim y...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51563 entries, 0 to 51562
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   talimat  51563 non-null  object
#  1    çıktı   51563 non-null  object
# dtypes: object(2)
# memory usage: 805.8+ KB

# %%
df = df.rename(columns={"talimat": "instruction", " çıktı": "output"})

# %%
df['instruction'] = df['instruction'].str.strip()
df['output'] = df['output'].str.strip()

# %%
df = df.sample(n=2000, random_state=42)
df
# Out:
#                                              instruction  \
# 13835                 Zümrüt yeşili rengini açıklayınız.
# 47683  Birim dönüştürme problemi için bir kopya kağıd...
# 12619  Sınavda başarısız olan birine cesaret verici b...
# 30937  Makine öğrenimi modellerindeki önyargıları anl...
# 37119  İyi para getiren ama tatil olmayan bir işi tan...
# ...                                                  ...
# 36652  Yeni bir rozet tasarımı için bir pazarlama kam...
# 5874   Girişte bir cümle verildiğinde, tüm tekil isim...
# 15631  Bu iki hikayenin neden farklı bir tonu olduğun...
# 10801    Çevik proje yönetimi metodolojisini tanımlayın.
# 15010  Bir halkla ilişkiler kampanyası geliştirmek iç...
#
#                                                   output
# 13835  Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar...
# 47683  1 milimetre = 0,0393701 inç 375 milimetre = 14...
# 12619  Bazen başarısız olmak iyidir. Başarısızlık, öğ...
# 30937  Makine öğrenimi modellerindeki önyargıları anl...
# 37119  İyi maaş veren ancak tatil olmayan bir iş, tip...
# ...                                                  ...
# 36652  Özel Emaye Rozetler için bir promosyon kampany...
# 5874                                    Kediler koşuyor.
# 15631  Hikaye 1, adamın girişimci niteliklerini vurgu...
# 10801  Çevik, kısa geliştirme döngülerini, sürekli iy...
# 15010  Bir halkla ilişkiler kampanyası geliştirmek iç...
#
# [2000 rows x 2 columns]

# %%
df = df.sample(n=2000, random_state=42)
df.head()
df.to_csv("asdasd.csv")

# %% [markdown]
# ## EMBEDDING

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import os
import matplotlib.pyplot as plt
from collections import Counter, defaultdict

# %%
output_dir = "embeddings"
os.makedirs(output_dir, exist_ok=True)

# %%
models = {
    "cosmos-colbert" : "ytu-ce-cosmos/turkish-colbert",
    "minilm": "sentence-transformers/all-MiniLM-L12-v2",
    "bge": "BAAI/bge-m3",
    "jina" : "jinaai/jina-embeddings-v3",
    "gte" : "thenlper/gte-large"
}

# %%
#!pip install requests==2.27.1

# %%
# Generates and saves embeddings for a list of texts using a specified pretrained model.
# It tokenizes the texts, passes them through the model to extract embeddings, and saves the embeddings as a .npy file.
def get_embeddings(texts, model_name, save_path):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)

    embeddings = []
    for text in texts:
        inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
        with torch.no_grad():
            outputs = model(**inputs)
            embedding = outputs.last_hidden_state[:, 0, :].squeeze().numpy()
        embeddings.append(embedding)

    embeddings = np.array(embeddings)
    np.save(save_path, embeddings) # Save the embeddings to the specified path as a .npy file

# %%
for model_name, model_path in models.items():
    print(f"Processing model: {model_name}")
    
    instruction_save_path = os.path.join(output_dir, f"{model_name}_instruction_embeddings.npy")
    get_embeddings(df["instruction"], model_path, instruction_save_path)
    
    output_save_path = os.path.join(output_dir, f"{model_name}_output_embeddings.npy")
    get_embeddings(df["output"], model_path, output_save_path)

print("Saved embedding files.")
# Out:
# Processing model: cosmos-colbert
# Processing model: minilm
# Processing model: bge
# Processing model: jina
# Processing model: gte
# Saved embedding files.

# %% [markdown]
# ## RETRIEVAL TOP1 VE TOP5 RESULT

# %%
# Finds top-k similar embeddings for each input embedding.
# Uses cosine similarity to measure similarity.
# Returns indices and similarity scores of top-k matches.

def find_top_matches(instruction_embeddings, output_embeddings, top_k=5): 
    results = []
    similarities_list = []
    for instruction in instruction_embeddings:
        similarities = cosine_similarity([instruction], output_embeddings)[0]
        top_indices = similarities.argsort()[-top_k:][::-1]
        results.append(top_indices)
        similarities_list.append(similarities[top_indices])
    return results, similarities_list

# %%
# Calculates Top-1 and Top-5 success rates for a matching task.
# Compares original outputs with retrieved outputs from top_matches.
# Returns success rates as percentages for Top-1 and Top-5 matches.

def calculate_success_rate(df, top_matches):
    top1_success = 0
    top5_success = 0

    for i, indices in enumerate(top_matches):
        original_output = df.iloc[i]['output']
        retrieved_outputs = [df.iloc[idx]['output'] for idx in indices]
        if original_output == retrieved_outputs[0]:
            top1_success += 1
        if original_output in retrieved_outputs:
            top5_success += 1

    top1_rate = top1_success / len(df) * 100
    top5_rate = top5_success / len(df) * 100

    return top1_rate, top5_rate

# %%
results = {}
for model_name in models:
    print(f"MODEL: {model_name.upper()}")
    
    instruction_embeddings = np.load(os.path.join(output_dir, f"{model_name}_instruction_embeddings.npy"))
    output_embeddings = np.load(os.path.join(output_dir, f"{model_name}_output_embeddings.npy"))

    top_matches, similarities_list = find_top_matches(instruction_embeddings, output_embeddings)

    for i, (indices, similarities) in enumerate(zip(top_matches, similarities_list)):
        if i >= 10: 
            break
        original_output = df.iloc[i]['output']
        top1_output = df.iloc[indices[0]]['output']
        top5_outputs = [df.iloc[idx]['output'] for idx in indices]

        print(f"\n=== Question {i+1} ===")
        print(f"Instruction: {df.iloc[i]['instruction']}")
        print(f"Original Answer: {original_output}\n")
        print(f"Top 1 Answer: {top1_output} (Similarity: {similarities[0]:.4f})\n")
        print("Top 5 Answers:")
        for rank, (answer, similarity) in enumerate(zip(top5_outputs, similarities), 1):
            print(f"  {rank}. {answer} (Similarity: {similarity:.4f})")

    top1_rate, top5_rate = calculate_success_rate(df, top_matches)
    results[model_name] = {"top1": top1_rate, "top5": top5_rate}
# Out:
# MODEL: COSMOS-COLBERT
#
# === Question 1 ===
# Instruction: Zümrüt yeşili rengini açıklayınız.
# Original Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur.
#
# Top 1 Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.9284)
#
# Top 5 Answers:
#   1. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.9284)
#   2. Kırmızı sıcak bir renktir. (Similarity: 0.9271)
#   3. Kırmızı ve Mavi'nin her ikisi de ana renklerdir, ancak Kırmızı çok daha parlaktır ve bir sıcaklığı vardır, Mavi ise daha soğuk ve sakindir. Sarı, tipik olarak neşeyle ilişkilendirilen ikincil bir renktir, Kırmızı ve Mavi ise genellikle daha yoğun olarak görülür. (Similarity: 0.9201)
#   4. Turuncu, sarıdan kırmızıya kadar değişen canlı ve sıcak tonlara sahip parlak bir renktir. C vitamini, enerji ve eğlence ile güçlü çağrışımları olan neşeli bir renktir. (Similarity: 0.9094)
#   5. Aurora'nın renkleri, güneşten salınan elektrik yüklü parçacıklar ile Dünya atmosferindeki gazlar arasındaki çarpışmalardan kaynaklanır. Bu parçacıklar atmosfere girerek farklı yüksekliklerde oksijen ve nitrojen atomları ile çarpışırlar. Bu çarpışmalar, kutup ışıklarında görülen kırmızı, yeşil ve mavi renkleri veren ışık parçacıkları olan fotonların salınmasına yol açar. Renkler, vurulan gazın türüne ve yüksekliğine bağlıdır. (Similarity: 0.9035)
#
# === Question 2 ===
# Instruction: Birim dönüştürme problemi için bir kopya kağıdı hazırlayın. 375 milimetreyi inç'e dönüştürün.
# Original Answer: 1 milimetre = 0,0393701 inç 375 milimetre = 14,724409448818898 inç
#
# Top 1 Answer: ``` matplotlib.pyplot'u plt x = [1, 2, 3] y = [4, 5, 6] olarak içe aktarın plt.plot(x, y) plt.xlabel('x') plt.ylabel('y') ) plt.title('Çizgi Grafik') plt.show() ``` (Similarity: 0.8676)
#
# Top 5 Answers:
#   1. ``` matplotlib.pyplot'u plt x = [1, 2, 3] y = [4, 5, 6] olarak içe aktarın plt.plot(x, y) plt.xlabel('x') plt.ylabel('y') ) plt.title('Çizgi Grafik') plt.show() ``` (Similarity: 0.8676)
#   2. Bir piramidin hacmini hesaplamak üzere bir algoritma oluşturmak için aşağıdaki formülü kullanabilirsiniz: Hacim = (Taban Alanı * Yükseklik) / 3. Taban alanını hesaplamak için piramidin taban alanını hesaplamanız gerekir. Taban alanını hesaplama formülü Taban Alanı = (Uzunluk * Genişlik) şeklindedir. Bu formül ile bir piramidin hacmini hesaplayabilirsiniz. (Similarity: 0.8630)
#   3. Algoritma: 1. 'reversedString' adında boş bir dizi oluşturun. 2. Verilen dizgiyi yineleyin ve her karakteri reversedString'in başına ekleyin. 3. reversedString'i döndürün. (Similarity: 0.8561)
#   4. Şu örnek değişkenlere sahip Dog adlı bir sınıf tasarlayın: ad, cins ve yaş. Sınıfın ayrıca bu üç parametreyi alan ve ilgili örnek değişkenlerini atayan bir yapıcısı olmalıdır. "Woof!" dizesini yazdıran bark() adlı bir yöntem yazın. Son olarak, bir Dog nesnesi oluşturan ve onun bark() yöntemini çağıran bir main() yöntemi yazın. (Similarity: 0.8492)
#   5. Bir makine öğrenimi modelini işlemek için önce ham verileri toplamanız, biçimlendirmeniz ve temizlemeniz gerekir. Ardından, veriler tren ve test setlerine ayrılmalı ve ardından ön işleme tabi tutulmalıdır. Veriler hazır olduğunda, model oluşturulabilir, eğitilebilir ve doğruluk açısından değerlendirilebilir. Son olarak, model kurulum için ayarlanmalı ve test edilmelidir. (Similarity: 0.8489)
#
# === Question 3 ===
# Instruction: Sınavda başarısız olan birine cesaret verici bir şey söyleyin.
# Original Answer: Bazen başarısız olmak iyidir. Başarısızlık, öğrenme sürecinin bir parçasıdır. Bu deneyimi daha fazlasını öğrenmek ve bir dahaki sefere daha iyisini yapmak için bir fırsat olarak kullanabileceksiniz.
#
# Top 1 Answer: Bu durumda, kendinizi tekrar etmek, söylemeye çalıştığınız şeyi vurgulamanıza yardımcı olabilir. (Similarity: 0.8854)
#
# Top 5 Answers:
#   1. Bu durumda, kendinizi tekrar etmek, söylemeye çalıştığınız şeyi vurgulamanıza yardımcı olabilir. (Similarity: 0.8854)
#   2. Sesiniz duyulmuyormuş gibi hissetmekten bıktınız mı? O zaman sandıkta sesini duyurduğunuzdan emin olun. Demokrasimizde söz sahibi olmanın en etkili yolu oy kullanmaktır. Çıkmayı ve oy vermeyi unutmayın. Senin fikrin önemli! (Similarity: 0.8449)
#   3. Dik durmak, her an korkmamak, Kazanmak için her şey, ağıt için gösterecek bir şey yok. Bir cesaret ve güç şarkısı söyle, Hiç şüphe yok, sonuna kadar git. Yol bilinmese de yürü, Cesaret bulacaksın ve güçlü bir şekilde yükseleceksin. Korkularla yüzleşin, onları bir kenara itin, Rehberiniz olarak cesaretle yola devam edin. Azabın ve dehşetin üzerine çık, Göklere, cesaretin yayıldığını gör. (Similarity: 0.8448)
#   4. Profesör ikna edici bir şekilde konuştu. (Similarity: 0.8405)
#   5. 1. "Ah oğlum, yine başlıyoruz!" 2. "Kolay olmayacak, sana bu kadarını anlatabilirim!" 3. "Vay canına, o da neydi?!" 4. "Belanın sesi geliyor!" 5. "Önümüze ne çıkarsa çıksın hazırlanalım!" (Similarity: 0.8394)
#
# === Question 4 ===
# Instruction: Makine öğrenimi modellerindeki önyargıları anlamanın neden önemli olduğunu açıklayın.
# Original Answer: Makine öğrenimi modellerindeki önyargıları anlamak önemlidir çünkü bu önyargılar genellikle istenmeyen sonuçlara yol açabilir. Önyargı, bir model popülasyonun gerçek çeşitliliğini temsil etmeyen verilerle eğitildiğinde ortaya çıkabilir. Bu, yanlış, adaletsiz ve hatta mevcut eşitsizliği devam ettirebilecek modellerle sonuçlanabilir. Bu önyargıları anlamak, modellerin hem doğru hem de herhangi bir önyargıdan arınmış bir şekilde oluşturulmasını sağlamak için önemlidir. Bu, potansiyel önyargılar için veri setini analiz etmek, popülasyonun çeşitliliğini yakalayan üretken modelleri kullanmak ve tutarsızlıkları tespit etmek ve ele almak için adalet ölçümlerini kullanmak gibi çeşitli yaklaşımları içerebilir.
#
# Top 1 Answer: Makine öğrenimi modellerindeki önyargıları anlamak önemlidir çünkü bu önyargılar genellikle istenmeyen sonuçlara yol açabilir. Önyargı, bir model popülasyonun gerçek çeşitliliğini temsil etmeyen verilerle eğitildiğinde ortaya çıkabilir. Bu, yanlış, adaletsiz ve hatta mevcut eşitsizliği devam ettirebilecek modellerle sonuçlanabilir. Bu önyargıları anlamak, modellerin hem doğru hem de herhangi bir önyargıdan arınmış bir şekilde oluşturulmasını sağlamak için önemlidir. Bu, potansiyel önyargılar için veri setini analiz etmek, popülasyonun çeşitliliğini yakalayan üretken modelleri kullanmak ve tutarsızlıkları tespit etmek ve ele almak için adalet ölçümlerini kullanmak gibi çeşitli yaklaşımları içerebilir. (Similarity: 0.9410)
#
# Top 5 Answers:
#   1. Makine öğrenimi modellerindeki önyargıları anlamak önemlidir çünkü bu önyargılar genellikle istenmeyen sonuçlara yol açabilir. Önyargı, bir model popülasyonun gerçek çeşitliliğini temsil etmeyen verilerle eğitildiğinde ortaya çıkabilir. Bu, yanlış, adaletsiz ve hatta mevcut eşitsizliği devam ettirebilecek modellerle sonuçlanabilir. Bu önyargıları anlamak, modellerin hem doğru hem de herhangi bir önyargıdan arınmış bir şekilde oluşturulmasını sağlamak için önemlidir. Bu, potansiyel önyargılar için veri setini analiz etmek, popülasyonun çeşitliliğini yakalayan üretken modelleri kullanmak ve tutarsızlıkları tespit etmek ve ele almak için adalet ölçümlerini kullanmak gibi çeşitli yaklaşımları içerebilir. (Similarity: 0.9410)
#   2. Verileri analiz ederek ve kalıpları tanımlayarak içgörüler elde edebilir ve daha bilinçli kararlar verebilirsiniz. (Similarity: 0.8963)
#   3. 1. Çevrimiçi öğretimdeki deneyiminiz ve yeterliliğiniz nedir? 2. Materyalin anlaşılmasını ve kavranmasını sağlamak için hangi stratejileri kullanıyorsunuz? 3. Öğrencilerin çevrimiçi öğrenirken katılımlarını sürdürmelerini nasıl sağlayacaksınız? 4. Özel öğrenme ihtiyacı olan öğrencilerle çalışmak için hangi materyalleri kullanırdınız? 5. Öğrenci ilerlemesini izlemek için hangi araçları kullanıyorsunuz? 6. Öğrenci veya veli sorularını veya şikayetlerini nasıl ele alıyorsunuz? 7. Çevrimiçi eğitime özgü öğrenmeyi değerlendirmek için hangi stratejileri kullanıyorsunuz? 8. Özel ders yaklaşımınıza kefil olabilecek velilerin veya öğrencilerin referanslarını bize sağlayabilir misiniz? (Similarity: 0.8813)
#   4. Büyük verilerin kullanımındaki etik sorunlardan biri, ayrımcılık potansiyelidir. Büyük veri modelleri, geçmiş verilerdeki kalıpların gelecekteki sonuçları tahmin etmek için kullanılabileceği önermesi üzerine kuruludur. Ancak, bu modeller taraflı veya ayrımcı verilere dayanıyorsa, kendileri taraflı veya ayrımcı olan kararlara yol açacaktır. Bu, ırk, din, cinsiyet veya diğer herhangi bir demografik faktöre dayalı olarak kredi veya istihdam fırsatları gibi hizmetlere eşit olmayan erişim şeklinde kendini gösterebilir. Büyük veride etik, verilerin ve algoritmaların belirli bir gruba karşı ayrımcılık yapmak için kullanılmamasını sağlamalıdır. (Similarity: 0.8793)
#   5. Makalenin ikinci paragrafı şöyledir: "Yaşadığımız dünyanın karmaşıklığını anlamanın tek yolu, farklı yerleri, kültürleri ve koşulları karşılaştırabilmek ve karşılaştırabilmektir. Bunu yapmak için, verilere güvenebilmek gerekir. güvenilir kaynaklardan. Örneğin, iki ülkeyi karşılaştırırken farklılıkları anlamanın en iyi yolu, ilgili nüfus büyüklüklerine bakmaktır." (Similarity: 0.8793)
#
# === Question 5 ===
# Instruction: İyi para getiren ama tatil olmayan bir işi tanımlayın.
# Original Answer: İyi maaş veren ancak tatil olmayan bir iş, tipik olarak hava trafik kontrolörü veya anestezi uzmanı gibi uzman bir roldür. Bu tür pozisyonlar yüksek talep görmektedir ve genellikle resmi tatillerde ve hafta sonlarında çalışmayı gerektirir, bu da kişiye fazladan çalışma saatleri için ödeme yapılması anlamına gelir.
#
# Top 1 Answer: "Kedileri gütmek gibi" deyişinin, bir kişinin yönlendirmesi veya kontrol etmesi imkansız olan bir şeyi veya birini organize etmeye veya kontrol etmeye yönelik beyhude girişimlerine atıfta bulunduğu söylenir. Bu ifade eski bir İrlanda atasözünden gelir: "Kedileri gütemezsiniz, çünkü onlar aynı ayak izlerinden gitmezler". Kavram genellikle tamamlanması imkansız veya zor olan bir çabayı veya görevi tanımlamak için kullanılır. (Similarity: 0.9017)
#
# Top 5 Answers:
#   1. "Kedileri gütmek gibi" deyişinin, bir kişinin yönlendirmesi veya kontrol etmesi imkansız olan bir şeyi veya birini organize etmeye veya kontrol etmeye yönelik beyhude girişimlerine atıfta bulunduğu söylenir. Bu ifade eski bir İrlanda atasözünden gelir: "Kedileri gütemezsiniz, çünkü onlar aynı ayak izlerinden gitmezler". Kavram genellikle tamamlanması imkansız veya zor olan bir çabayı veya görevi tanımlamak için kullanılır. (Similarity: 0.9017)
#   2. Yaklaşan: Yakın gelecekte gerçekleşmesi muhtemel. Azim: Başarıya ulaşmada zorluk veya gecikmeye rağmen bir şeyi yapmada kararlılık. Yorucu: Çok yorucu veya talepkar, örneğin yorucu bir egzersiz rejimi. (Similarity: 0.8926)
#   3. YOLO, “Sadece Bir Kez Yaşarsınız” anlamına gelen bir kısaltmadır. Genellikle risk almaya veya hayatı dolu dolu yaşamaya yönelik tasasız bir tavrı ifade etmek için kullanılır. (Similarity: 0.8911)
#   4. Kelime dağarcığı kelimeleri: Ben, bisiklete binmek, kumsal, yarın. (Similarity: 0.8846)
#   5. 1. Eğitimin önemi. 2. Sosyal medya ve teknoloji kullanımını dengelemek. 3. İyi ilişkiler kurmak. 4. Hedef belirlemenin gücü. 5. Müfredat dışı faaliyetlerde bulunmak. (Similarity: 0.8832)
#
# === Question 6 ===
# Instruction: Krep yapmak için bir tarif yazın.
# Original Answer: Malzemeler: - 1½ su bardağı çok amaçlı un - 2 yemek kaşığı şeker - 2 çay kaşığı kabartma tozu - ½ çay kaşığı kabartma tozu - ¼ çay kaşığı tuz - 1 su bardağı süt - 2 yemek kaşığı eritilmiş tereyağı - 1 büyük yumurta - 2 çay kaşığı bitkisel yağ Talimatlar: 1. Büyük bir kapta un, şeker, kabartma tozu, kabartma tozu ve tuzu birlikte çırpın. 2. Ayrı bir kapta süt, tereyağı, yumurta ve sıvı yağı çırpın. 3. Süt karışımını un karışımına dökün ve birleşene kadar karıştırın. 4. Yağlanmış bir tavayı orta-yüksek ateşte ısıtın. 5. Hamurun ¼ fincanını sıcak tavaya bırakın ve kenarlar kuruyana ve yüzeyde kabarcıklar görünene kadar pişirin. 6. Pankeki çevirin ve diğer tarafı altın rengi olana kadar yaklaşık 1-2 dakika pişirin. 7. Pankeki bir tabağa aktarın ve kalan hamurla aynı işlemi tekrarlayın. İstenilen soslarla sıcak servis yapın.
#
# Top 1 Answer: Kıyma, patates, soğan ve sarımsak ile Çoban Böreği gibi bir yemek yapabilirsiniz. (Similarity: 0.8965)
#
# Top 5 Answers:
#   1. Kıyma, patates, soğan ve sarımsak ile Çoban Böreği gibi bir yemek yapabilirsiniz. (Similarity: 0.8965)
#   2. Ev yapımı guacamole yapmak için avokadoyu çatalla ezerek başlayın. Ardından yemeklik doğranmış soğan, sarımsak, kişniş ve küp doğranmış domatesleri ekleyin. Yarım misket limonunun suyunu karıştırın ve tadına bakmak için tuz ve karabiber ekleyin. Baharatlı bir versiyon için biraz jalapeno biberi ekleyin. Eğlence! (Similarity: 0.8922)
#   3. Temel bir kek yapmak için gerekli malzemeler un, şeker, kakao tozu, kabartma tozu, tuz, tereyağı, yumurta ve vanilya özüdür. (Similarity: 0.8868)
#   4. 1. Pişirmeye başlamadan önce tüm malzemelerinizin önceden hazır olduğundan ve yerleştirildiğinden emin olun. Bu, daha sonra malzemeleri veya öğeleri aramak için harcadığınız zamandan tasarruf etmenizi sağlayacaktır. 2. Her şeyi sıfırdan hazırlamak veya pişirmek yerine, önceden doğranmış sebzeler, konserve fasulye veya hazır soslar gibi pişirme kısayollarını kullanın. (Similarity: 0.8777)
#   5. Kek yapmak için gerekli malzemeler: - 2 su bardağı çok amaçlı un - 2 çay kaşığı kabartma tozu - ½ çay kaşığı kabartma tozu - 1 tutam tuz - 3 büyük yumurta - 1 su bardağı toz şeker - ½ su bardağı eritilmiş tereyağı - ½ su bardağı bitkisel yağ - ¾ su bardağı ayran - 2 çay kaşığı vanilya özü (Similarity: 0.8753)
#
# === Question 7 ===
# Instruction: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi seçin
# Original Answer: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır.
#
# Top 1 Answer: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır. (Similarity: 0.9233)
#
# Top 5 Answers:
#   1. Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır. (Similarity: 0.9233)
#   2. İnterneti güvenli ve sorumlu bir şekilde kullanmanın en iyi yolu, güçlü parolalar kullandığınızdan emin olmak, mümkün olduğunda iki faktörlü kimlik doğrulamayı (2FA) etkinleştirmek, yalnızca güvenli web sitelerini ziyaret etmek, virüsten koruma ve kötü amaçlı yazılımdan koruma yazılımı yüklemek, asla şüpheli bağlantılara tıklamamak, kaçınmaktır. kişisel bilgileri vermekten kaçının ve kimlik avı dolandırıcılıklarından haberdar olun. Ek olarak, çevrimiçi olarak yayınlananlara dikkat etmek ve sosyal medyada bilgi göndermenin ve paylaşmanın potansiyel risklerinin farkında olmak önemlidir. (Similarity: 0.8436)
#   3. Sistem, metni analiz etmek ve kişisel saldırılar, tehditler ve aşağılayıcı dil gibi siber zorbalık belirtilerini tespit etmek için doğal dil işleme algoritmaları kullanmalıdır. Sistem, siber zorbalığı daha iyi tespit etmek için katılımcıların yaşı ve ilişkisi gibi bağlamsal bilgileri de dikkate almalıdır. (Similarity: 0.8295)
#   4. DSÖ, ikinci bir vaka dalgası olasılığını azaltmak için toplum içinde yüz maskesi takmak, fiziksel mesafe koymak, büyük toplantılardan kaçınmak ve sık sık el yıkamak gibi sürekli sosyal mesafe önlemlerine duyulan ihtiyacı vurguladı. Ek olarak kuruluş, yeni vakaları hızlı bir şekilde tespit etmek ve gerektiğinde hedeflenen tecritleri yürürlüğe koymak için ülkeleri test kapasitesini artırmaya teşvik ediyor. (Similarity: 0.8130)
#   5. Facebook'un devam eden birkaç gizlilik girişimi vardır ve bunlardan en önemlisi Gizlilik İlkeleri girişimidir. Bu program, kullanıcı verilerinin korunmasını sağlamak için tasarlanmış veri sorumluluğu, şeffaflık, bütünlük, adalet ve güvenlik gibi temel ilkeleri ana hatlarıyla belirtir. Politika ayrıca, kullanıcı verilerinin üçüncü taraf ortaklarla nasıl paylaşılabileceğini ve kullanıcı verilerinin uluslararası sınırlar ötesine nasıl aktarılabileceğini ana hatlarıyla belirtir. (Similarity: 0.8098)
#
# === Question 8 ===
# Instruction: Verilen son tarihe kadar bir ödevi teslim etmediğiniz için özür dilemek için bir özür mektubu oluşturun.
# Original Answer: Ödevimi belirtilen son tarihe kadar teslim edemediğim için özür dilemek için yazıyorum. Bunu yapmanın benim sorumluluğum olduğunu anlıyorum ve bu hatanın tüm sorumluluğunu kabul ediyorum. Verdiği rahatsızlıktan dolayı gerçekten üzgünüm. Aynı hatayı bir daha yapmamaya özen göstereceğim.
#
# Top 1 Answer: Ödevimi belirtilen son tarihe kadar teslim edemediğim için özür dilemek için yazıyorum. Bunu yapmanın benim sorumluluğum olduğunu anlıyorum ve bu hatanın tüm sorumluluğunu kabul ediyorum. Verdiği rahatsızlıktan dolayı gerçekten üzgünüm. Aynı hatayı bir daha yapmamaya özen göstereceğim. (Similarity: 0.9198)
#
# Top 5 Answers:
#   1. Ödevimi belirtilen son tarihe kadar teslim edemediğim için özür dilemek için yazıyorum. Bunu yapmanın benim sorumluluğum olduğunu anlıyorum ve bu hatanın tüm sorumluluğunu kabul ediyorum. Verdiği rahatsızlıktan dolayı gerçekten üzgünüm. Aynı hatayı bir daha yapmamaya özen göstereceğim. (Similarity: 0.9198)
#   2. Yarınki etkinliği acilen ele almamız gerekiyor, yoksa son tarihe kadar gönderilecek bir hikaye olmayacak. (Similarity: 0.8770)
#   3. Bu sorunu hızlı bir şekilde çözmemiz gerekiyor. - Bu projede herhangi bir gecikmeye müsamaha gösteremem. - Sözleşmeyi dikkatlice imzalamalıyız. - Her belge düzgün bir şekilde gözden geçirilmelidir. (Similarity: 0.8716)
#   4. Program, belirtilen web sitesine bir HTTP isteği oluşturmalı ve ardından HTML yanıt kodunu almalı ve ayrıştırmalıdır. Ayrıca 404 sayfa gibi hataları da işleyebilmeli ve kullanıcıya anlamlı bir hata mesajı gösterebilmelidir. (Similarity: 0.8595)
#   5. Ödünç alınan bir materyali iade etmek için makul bir beklenti, materyali zamanında ödünç alındığı gibi iade etmektir. Makul kabul edilen süre, borç veren ile borç alan arasındaki anlaşmaya bağlı olacaktır. Yürürlükte bir anlaşma yoksa, öğenin makul bir süre içinde, genellikle iki haftayı geçmeyecek şekilde iade edilmesi gerektiğini varsaymanız önerilir. (Similarity: 0.8522)
#
# === Question 9 ===
# Instruction: En çok yönlü beş bitkiyi adlandırın.
# Original Answer: En çok yönlü beş bitki Tatlı Patates, Moringa, Nane, Mısır ve Kale'dir. Tatlı Patates, kaynatılabilen, buharda pişirilebilen veya kızartılabilen bir kök sebzedir. Moringa, taze veya kurutulmuş olarak yenebilen birçok yenilebilir parçaya sahip bir ağaçtır. Nane, yiyecek ve içecekleri tatlandırmak için kullanılabilen hızlı büyüyen bir bitkidir. Mısır, çeşitli yemeklerde kullanılabilen çok yönlü bir tahıldır. Son olarak Kale, çiğ, buharda pişirilmiş ve sotelenmiş olarak yenebilen besleyici ve çok yönlü yeşil yapraklı bir sebzedir.
#
# Top 1 Answer: Yaygın su bitkileri arasında nilüfer, hornwort, eelgrass, su mercimeği ve su sümbülü bulunur. (Similarity: 0.8773)
#
# Top 5 Answers:
#   1. Yaygın su bitkileri arasında nilüfer, hornwort, eelgrass, su mercimeği ve su sümbülü bulunur. (Similarity: 0.8773)
#   2. Bir evde muhafaza edilebilecek beş bitki; Aloe Vera, Kaktüs, Pothos, Barış Zambak ve Örümcek Bitkisidir. (Similarity: 0.8676)
#   3. En çok yönlü beş bitki Tatlı Patates, Moringa, Nane, Mısır ve Kale'dir. Tatlı Patates, kaynatılabilen, buharda pişirilebilen veya kızartılabilen bir kök sebzedir. Moringa, taze veya kurutulmuş olarak yenebilen birçok yenilebilir parçaya sahip bir ağaçtır. Nane, yiyecek ve içecekleri tatlandırmak için kullanılabilen hızlı büyüyen bir bitkidir. Mısır, çeşitli yemeklerde kullanılabilen çok yönlü bir tahıldır. Son olarak Kale, çiğ, buharda pişirilmiş ve sotelenmiş olarak yenebilen besleyici ve çok yönlü yeşil yapraklı bir sebzedir. (Similarity: 0.8550)
#   4. İsimler: bitki, çiçek Sıfatlar: lezzetli, akıllı (Similarity: 0.8343)
#   5. Kırmızı bir gül çiçeğini tanımlamak için beş tanımlayıcı sıfat: canlı, çekici, romantik, yumuşak ve güzel kokulu. (Similarity: 0.8241)
#
# === Question 10 ===
# Instruction: Belirli bir kelimenin başka bir kelimenin anagramı olup olmadığını kontrol etmek için bir algoritma oluşturun.
# Original Answer: 1. İki kelimeyi girdi olarak alın 2. Her kelimeyi küçük harfe çevirin 3. Her kelimedeki karakterleri ayrı ayrı alfabetik olarak sıralayın 4. Sıralanan kelimeleri karşılaştırın 5. Her ikisi de aynıysa, kelimeler anagramdır Aksi takdirde kelimeler anagram değildir .
#
# Top 1 Answer: 1. İki kelimeyi girdi olarak alın 2. Her kelimeyi küçük harfe çevirin 3. Her kelimedeki karakterleri ayrı ayrı alfabetik olarak sıralayın 4. Sıralanan kelimeleri karşılaştırın 5. Her ikisi de aynıysa, kelimeler anagramdır Aksi takdirde kelimeler anagram değildir . (Similarity: 0.9264)
#
# Top 5 Answers:
#   1. 1. İki kelimeyi girdi olarak alın 2. Her kelimeyi küçük harfe çevirin 3. Her kelimedeki karakterleri ayrı ayrı alfabetik olarak sıralayın 4. Sıralanan kelimeleri karşılaştırın 5. Her ikisi de aynıysa, kelimeler anagramdır Aksi takdirde kelimeler anagram değildir . (Similarity: 0.9264)
#   2. Şu örnek değişkenlere sahip Dog adlı bir sınıf tasarlayın: ad, cins ve yaş. Sınıfın ayrıca bu üç parametreyi alan ve ilgili örnek değişkenlerini atayan bir yapıcısı olmalıdır. "Woof!" dizesini yazdıran bark() adlı bir yöntem yazın. Son olarak, bir Dog nesnesi oluşturan ve onun bark() yöntemini çağıran bir main() yöntemi yazın. (Similarity: 0.9146)
#   3. Belirli bir dizinin bir palindrom olup olmadığını, diziyi tersine çevirerek ve tersine çevrilmiş diziyi orijinal diziyle karşılaştırarak kontrol edebilirsiniz. Aynıysa, dize bir palindromdur. (Similarity: 0.9125)
#   4. Bir veritabanından veri almak için uygun bir sorgulama dili kullanmalısınız. En yaygın sorgulama dili Yapılandırılmış Sorgu Dili'dir (SQL). Dil, hangi veri sütunlarını almak istediğinizi ve alınan verileri nasıl sıralamak istediğinizi belirlemenize olanak tanır. Ayrıca, eşleşen veriler için bir koşul gibi belirttiğiniz diğer tüm ölçütler, doğru verileri almak için sorguya dahil edilmelidir. (Similarity: 0.9108)
#   5. Bu problem için uygun Makine Öğrenimi algoritması lojistik regresyondur. (Similarity: 0.9051)
# MODEL: MINILM
#
# === Question 1 ===
# Instruction: Zümrüt yeşili rengini açıklayınız.
# Original Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur.
#
# Top 1 Answer: Nisan ayında meydana gelen yağışlar, Mayıs ayında rengarenk çiçek açacaktır. (Similarity: 0.8623)
#
# Top 5 Answers:
#   1. Nisan ayında meydana gelen yağışlar, Mayıs ayında rengarenk çiçek açacaktır. (Similarity: 0.8623)
#   2. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.8205)
#   3. Yazıyorum. (Similarity: 0.8160)
#   4. Tasarımın iki unsuru denge ve renktir. (Similarity: 0.8140)
#   5. Mutlulukla en çok ilişkilendirilen renkler parlak maviler, sarılar, turuncular ve yeşillerdir. Bu renkler umut, enerji ve iyimserlik duygularını çağrıştırır. Bir kişinin ruh hali üzerinde olumlu etkileri olabileceğinden, genellikle perakende mağazaları ve restoranlar gibi ortamlarda kullanılırlar. (Similarity: 0.8084)
#
# === Question 2 ===
# Instruction: Birim dönüştürme problemi için bir kopya kağıdı hazırlayın. 375 milimetreyi inç'e dönüştürün.
# Original Answer: 1 milimetre = 0,0393701 inç 375 milimetre = 14,724409448818898 inç
#
# Top 1 Answer: Birinci Sanayi Devrimi, yeni güç kaynakları, üretim ve ulaşım yöntemleri ve ekonomik uzmanlaşma getirerek küresel ekonomiyi dönüştürdü. (Similarity: 0.7905)
#
# Top 5 Answers:
#   1. Birinci Sanayi Devrimi, yeni güç kaynakları, üretim ve ulaşım yöntemleri ve ekonomik uzmanlaşma getirerek küresel ekonomiyi dönüştürdü. (Similarity: 0.7905)
#   2. I. Giriş A. İş Kavramına Genel Bakış B. Hedef Müşteri C. Misyon Bildirimi II. Pazar Analizi A. Sektöre Genel Bakış B. Hedef Pazar C. Rakipleri Analiz Etme III. Strateji ve Uygulama A. Şirket Yapısı B. Sunulan Hizmetler C. Konum D. Yönetim ve Çalışanlar IV. Mali Plan A. Gelir Projeksiyonu B. Maliyet Yapısı C. Finansman D. Kâr ve Zarar Projeksiyonu (Similarity: 0.7885)
#   3. Son zamanlardaki büyük bir veri ihlali, bilgisayar korsanlarının 140 milyondan fazla ABD tüketicisinin kişisel bilgilerine erişebildiği 2017'deki Equifax ihlaliydi. (Similarity: 0.7870)
#   4. Aşk kolay gelmez dedi, bu bir alıp verme oyunudur. (Similarity: 0.7858)
#   5. Herkese iyi akşamlar! 2021'in mezun olan sınıfını kutlamak için bu akşam burada olmak benim için bir zevk. Hepiniz büyük bir dönüm noktasına ulaştığınız için bugün çok özel bir gün: mezuniyet. Hepiniz bu önemli olaya dönüp baktığınızda, son birkaç yılda başardığınız her şeyle gurur duymanızı istiyorum. Hedeflerinize ulaşmak için son birkaç yılın zorluklarını aştığınız için kendinizle gurur duymalısınız. Büyük hayaller kurmaya, yıldızlara ulaşmaya ve asla pes etmemeye teşvik ediyorum. Hepinizi tebrik ediyoruz ve gelecekte harika şeylerle ilerlemenizi diliyoruz! (Similarity: 0.7838)
#
# === Question 3 ===
# Instruction: Sınavda başarısız olan birine cesaret verici bir şey söyleyin.
# Original Answer: Bazen başarısız olmak iyidir. Başarısızlık, öğrenme sürecinin bir parçasıdır. Bu deneyimi daha fazlasını öğrenmek ve bir dahaki sefere daha iyisini yapmak için bir fırsat olarak kullanabileceksiniz.
#
# Top 1 Answer: Dik durmak, her an korkmamak, Kazanmak için her şey, ağıt için gösterecek bir şey yok. Bir cesaret ve güç şarkısı söyle, Hiç şüphe yok, sonuna kadar git. Yol bilinmese de yürü, Cesaret bulacaksın ve güçlü bir şekilde yükseleceksin. Korkularla yüzleşin, onları bir kenara itin, Rehberiniz olarak cesaretle yola devam edin. Azabın ve dehşetin üzerine çık, Göklere, cesaretin yayıldığını gör. (Similarity: 0.8007)
#
# Top 5 Answers:
#   1. Dik durmak, her an korkmamak, Kazanmak için her şey, ağıt için gösterecek bir şey yok. Bir cesaret ve güç şarkısı söyle, Hiç şüphe yok, sonuna kadar git. Yol bilinmese de yürü, Cesaret bulacaksın ve güçlü bir şekilde yükseleceksin. Korkularla yüzleşin, onları bir kenara itin, Rehberiniz olarak cesaretle yola devam edin. Azabın ve dehşetin üzerine çık, Göklere, cesaretin yayıldığını gör. (Similarity: 0.8007)
#   2. Harekete geçmek için kapanış saatine kadar beklediler ve silahlarıyla binaya girdiler. Personel hızla bastırıldı ve soyguncular bulabildikleri her parayı hızla aldılar. Yüzbinlerce doları alıp kaçtılar ama banka müdürü sessiz alarmı çalıştırıp polise haber vermeyi başardı. (Similarity: 0.7980)
#   3. Başarıyı ölçmenin yaygın bir yolu, hedeflere ulaşılıp ulaşılmadığını değerlendirmektir. Bir bireyin veya kuruluşun genel büyümesine ve gelişimine bakılarak da ölçülebilir. (Similarity: 0.7958)
#   4. 1. Yükselen deniz seviyeleri 2. Artan sıcaklıklar 3. Biyoçeşitliliğin kaybı 4. Daha aşırı hava koşulları 5. Eriyen kutup buzulları ve buzullar (Similarity: 0.7933)
#   5. Ev yapımı guacamole yapmak için avokadoyu çatalla ezerek başlayın. Ardından yemeklik doğranmış soğan, sarımsak, kişniş ve küp doğranmış domatesleri ekleyin. Yarım misket limonunun suyunu karıştırın ve tadına bakmak için tuz ve karabiber ekleyin. Baharatlı bir versiyon için biraz jalapeno biberi ekleyin. Eğlence! (Similarity: 0.7931)
#
# === Question 4 ===
# Instruction: Makine öğrenimi modellerindeki önyargıları anlamanın neden önemli olduğunu açıklayın.
# Original Answer: Makine öğrenimi modellerindeki önyargıları anlamak önemlidir çünkü bu önyargılar genellikle istenmeyen sonuçlara yol açabilir. Önyargı, bir model popülasyonun gerçek çeşitliliğini temsil etmeyen verilerle eğitildiğinde ortaya çıkabilir. Bu, yanlış, adaletsiz ve hatta mevcut eşitsizliği devam ettirebilecek modellerle sonuçlanabilir. Bu önyargıları anlamak, modellerin hem doğru hem de herhangi bir önyargıdan arınmış bir şekilde oluşturulmasını sağlamak için önemlidir. Bu, potansiyel önyargılar için veri setini analiz etmek, popülasyonun çeşitliliğini yakalayan üretken modelleri kullanmak ve tutarsızlıkları tespit etmek ve ele almak için adalet ölçümlerini kullanmak gibi çeşitli yaklaşımları içerebilir.
#
# Top 1 Answer: Derin öğrenme, karmaşık veri kümelerinden öğrenmek için çok katmanlı sinir ağlarını kullanan bir makine öğrenimi dalıdır. Sinir ağları, verilerdeki kalıpları tanımlamak için tasarlanmıştır, bu da onların oldukça doğru tahminler yapmalarını sağlar. Ağın her katmanı, modelin daha ayrıntılı ve ayrıntılı tahminler yapmasına izin vererek, verilerin farklı bir yönünden sorumludur. Derin öğrenme ağları, her katmandan alınan içgörüleri birleştirerek çok çeşitli görevlerde uzman düzeyinde tahminler ve kararlar verebilir. (Similarity: 0.8485)
#
# Top 5 Answers:
#   1. Derin öğrenme, karmaşık veri kümelerinden öğrenmek için çok katmanlı sinir ağlarını kullanan bir makine öğrenimi dalıdır. Sinir ağları, verilerdeki kalıpları tanımlamak için tasarlanmıştır, bu da onların oldukça doğru tahminler yapmalarını sağlar. Ağın her katmanı, modelin daha ayrıntılı ve ayrıntılı tahminler yapmasına izin vererek, verilerin farklı bir yönünden sorumludur. Derin öğrenme ağları, her katmandan alınan içgörüleri birleştirerek çok çeşitli görevlerde uzman düzeyinde tahminler ve kararlar verebilir. (Similarity: 0.8485)
#   2. Bu atasözü, hayatın en zor olduğu, şimdiki zamanın en karanlık olduğu anlarda, her şeyin sonunda daha iyi olacağına dair hâlâ bir umut olduğu anlamına gelir. İyimser kalmak için bir hatırlatmadır, çünkü en umutsuz anları bile gelecekte daha parlak zamanlar izleyebilir. (Similarity: 0.8458)
#   3. Makine öğrenimi modellerindeki önyargıları anlamak önemlidir çünkü bu önyargılar genellikle istenmeyen sonuçlara yol açabilir. Önyargı, bir model popülasyonun gerçek çeşitliliğini temsil etmeyen verilerle eğitildiğinde ortaya çıkabilir. Bu, yanlış, adaletsiz ve hatta mevcut eşitsizliği devam ettirebilecek modellerle sonuçlanabilir. Bu önyargıları anlamak, modellerin hem doğru hem de herhangi bir önyargıdan arınmış bir şekilde oluşturulmasını sağlamak için önemlidir. Bu, potansiyel önyargılar için veri setini analiz etmek, popülasyonun çeşitliliğini yakalayan üretken modelleri kullanmak ve tutarsızlıkları tespit etmek ve ele almak için adalet ölçümlerini kullanmak gibi çeşitli yaklaşımları içerebilir. (Similarity: 0.8454)
#   4. Verilen veri kümesindeki kalıpları tanımlamak için Karar Ağacı gibi bir makine öğrenimi modeli oluşturun. (Similarity: 0.8446)
#   5. Kaynak makinesi kullanırken belirli güvenlik önlemlerinin alınması önemlidir. Aleve dayanıklı eldivenler ve kolları ve bacakları tamamen kapatan uzun giysiler dahil olmak üzere uygun giysiler giyin. Alanın iyi havalandırıldığından ve yanıcı maddelerden arındırıldığından emin olun. Kaynak makinesinin iyi çalışır durumda olduğundan ve basınç regülatörü, gaz kesme vanası ve emniyet mandalı gibi gerekli tüm güvenlik özelliklerine sahip olduğundan emin olmak için kontrol edin. Ayrıca kaynak makinesini yakarken dikkatli olun ve yüzünüzü alevden uzak tutun. (Similarity: 0.8383)
#
# === Question 5 ===
# Instruction: İyi para getiren ama tatil olmayan bir işi tanımlayın.
# Original Answer: İyi maaş veren ancak tatil olmayan bir iş, tipik olarak hava trafik kontrolörü veya anestezi uzmanı gibi uzman bir roldür. Bu tür pozisyonlar yüksek talep görmektedir ve genellikle resmi tatillerde ve hafta sonlarında çalışmayı gerektirir, bu da kişiye fazladan çalışma saatleri için ödeme yapılması anlamına gelir.
#
# Top 1 Answer: IoT, sağlık, tarım, ev otomasyonu, akıllı şehirler, bağlantılı arabalar, askeri uygulamalar ve perakende gibi alanlarda kullanılmaktadır. (Similarity: 0.7977)
#
# Top 5 Answers:
#   1. IoT, sağlık, tarım, ev otomasyonu, akıllı şehirler, bağlantılı arabalar, askeri uygulamalar ve perakende gibi alanlarda kullanılmaktadır. (Similarity: 0.7977)
#   2. Kendi başıma çözebileceğimi düşünmüştüm ama yanılmışım... (Similarity: 0.7945)
#   3. Ağaç yaşayan bir organizmadır. (Similarity: 0.7938)
#   4. "Esenlik Bilimini Tanıtmak" - mutluluk ve sağlık arasındaki bağlantıları keşfetmek. (Similarity: 0.7921)
#   5. Annesi güçlü iradeli, sevgi dolu ve destekleyici bir kadındı. (Similarity: 0.7914)
#
# === Question 6 ===
# Instruction: Krep yapmak için bir tarif yazın.
# Original Answer: Malzemeler: - 1½ su bardağı çok amaçlı un - 2 yemek kaşığı şeker - 2 çay kaşığı kabartma tozu - ½ çay kaşığı kabartma tozu - ¼ çay kaşığı tuz - 1 su bardağı süt - 2 yemek kaşığı eritilmiş tereyağı - 1 büyük yumurta - 2 çay kaşığı bitkisel yağ Talimatlar: 1. Büyük bir kapta un, şeker, kabartma tozu, kabartma tozu ve tuzu birlikte çırpın. 2. Ayrı bir kapta süt, tereyağı, yumurta ve sıvı yağı çırpın. 3. Süt karışımını un karışımına dökün ve birleşene kadar karıştırın. 4. Yağlanmış bir tavayı orta-yüksek ateşte ısıtın. 5. Hamurun ¼ fincanını sıcak tavaya bırakın ve kenarlar kuruyana ve yüzeyde kabarcıklar görünene kadar pişirin. 6. Pankeki çevirin ve diğer tarafı altın rengi olana kadar yaklaşık 1-2 dakika pişirin. 7. Pankeki bir tabağa aktarın ve kalan hamurla aynı işlemi tekrarlayın. İstenilen soslarla sıcak servis yapın.
#
# Top 1 Answer: Milenyum Tarzını Yaşamak. (Similarity: 0.7844)
#
# Top 5 Answers:
#   1. Milenyum Tarzını Yaşamak. (Similarity: 0.7844)
#   2. Kişiselleştirilmiş bir tarif kitabı olarak hizmet veren bir akıllı telefon uygulaması. Kullanıcılar bir tarif veri tabanında arama yapabilir, tarifleri kendi zevklerine göre özelleştirebilir ve kendi dijital yemek kitaplarına kaydedebilir. Uygulama ayrıca kullanıcının diyet kısıtlamalarına ve diyet tercihlerine göre tarifler önerebilir ve her tarif hakkında beslenme bilgisi sağlayabilir. (Similarity: 0.7674)
#   3. Krep, mısır gevreği, yumurta. (Similarity: 0.7605)
#   4. Aşk kolay gelmez dedi, bu bir alıp verme oyunudur. (Similarity: 0.7527)
#   5. Giysi kumaştan yapılır. (Similarity: 0.7526)
#
# === Question 7 ===
# Instruction: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi seçin
# Original Answer: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır.
#
# Top 1 Answer: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır. (Similarity: 0.8944)
#
# Top 5 Answers:
#   1. Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır. (Similarity: 0.8944)
#   2. Şirket değerleri, bir işletmenin kültürünü ve amacını tanımlamada önemli bir rol oynar. Bir yön duygusu sağlar, çalışanların karar vermesine yardımcı olur ve işin yapılma şekline rehberlik eder. Bir şirket, herkesin bağlı kalabileceği birleşik bir değerler dizisi sunarak, ekibinin işbirliği içinde kararlar almasını ve ortak bir hedefe doğru çalışmasını sağlar. Şirket değerleri aynı zamanda ekip üyeleri arasında paylaşılan bir kimlik ve amaç duygusunu teşvik eder. (Similarity: 0.8635)
#   3. Şirketlerin çevrimiçi itibarlarını yönetebilmelerinin iki yolu, çevrimiçi varlıklarını aktif olarak izlemek ve müşterilerle etkileşim kurmaktır. Şirketler, çevrimiçi ortamda nasıl konuşulduğunun farkında olmalı ve şirketleriyle ilgili yorumları ve sosyal medya paylaşımlarını aktif olarak takip etmelidir. Ek olarak, şirketler web sitelerinde ve sosyal medya hesaplarında müşterilerle ve en son güncellemelerle etkileşim kurmalıdır. Bu, müşterilerle güven oluşturmaya yardımcı olacak ve onlara şirketin geri bildirimleriyle ilgilendiğini gösterecektir. (Similarity: 0.8630)
#   4. Bir sosyal medya varlığını sürdürmek, şirketler için önemlidir çünkü müşterileriyle etkileşim kurmalarına ve güçlü bir marka kimliği oluşturmalarına yardımcı olur. Sosyal medya aynı zamanda şirketlere ürün ve hizmetlerinin reklamını yapmak, duyuruları yayınlamak ve müşteri sorularını yanıtlamak için bir platform sağlar. Tüm bu faaliyetler, müşteri sadakatini artırmaya ve şirketi olumlu bir şekilde tanıtmaya yardımcı olabilir. (Similarity: 0.8612)
#   5. Müşterilere şirketle ilgili özel bir ürün koleksiyonu sunan ve kapılarına kadar teslim edilen aylık bir abonelik kutusu oluşturun. (Similarity: 0.8574)
#
# === Question 8 ===
# Instruction: Verilen son tarihe kadar bir ödevi teslim etmediğiniz için özür dilemek için bir özür mektubu oluşturun.
# Original Answer: Ödevimi belirtilen son tarihe kadar teslim edemediğim için özür dilemek için yazıyorum. Bunu yapmanın benim sorumluluğum olduğunu anlıyorum ve bu hatanın tüm sorumluluğunu kabul ediyorum. Verdiği rahatsızlıktan dolayı gerçekten üzgünüm. Aynı hatayı bir daha yapmamaya özen göstereceğim.
#
# Top 1 Answer: Bir özellik çıkarma algoritmasının birincil amacı, bir veri kümesinden anlamlı özellikleri belirlemek ve bunları daha kompakt bir temsile dönüştürmektir. Bu, verilerin karmaşıklığını azaltarak analiz etmeyi, sınıflandırmayı ve kümelemeyi kolaylaştırır. (Similarity: 0.8101)
#
# Top 5 Answers:
#   1. Bir özellik çıkarma algoritmasının birincil amacı, bir veri kümesinden anlamlı özellikleri belirlemek ve bunları daha kompakt bir temsile dönüştürmektir. Bu, verilerin karmaşıklığını azaltarak analiz etmeyi, sınıflandırmayı ve kümelemeyi kolaylaştırır. (Similarity: 0.8101)
#   2. Yeni bir araba satın aldıktan sonra yapılacak ilk şey, kullanım kılavuzunu okumak ve aracın özelliklerini, kontrollerini ve bakım gereksinimlerini öğrenmek olacaktır. (Similarity: 0.7775)
#   3. Resmin iki özelliği sarı elbiseli kadın ve bastonla yürümesidir. (Similarity: 0.7734)
#   4. Bu bilgi, özgeçmişin "Amaç" veya "Özet" bölümüne ait olacaktır. (Similarity: 0.7719)
#   5. TbF1y! Özel şifre, her kelimenin ilk harfini alıp ortasına bir sayı ve ! sonunda. T harfi The'yi temsil eder ve 1 rakamı uçmayı temsil eder. ! özel bir karakterdir. Çıktı TbF1y'dir! (Similarity: 0.7692)
#
# === Question 9 ===
# Instruction: En çok yönlü beş bitkiyi adlandırın.
# Original Answer: En çok yönlü beş bitki Tatlı Patates, Moringa, Nane, Mısır ve Kale'dir. Tatlı Patates, kaynatılabilen, buharda pişirilebilen veya kızartılabilen bir kök sebzedir. Moringa, taze veya kurutulmuş olarak yenebilen birçok yenilebilir parçaya sahip bir ağaçtır. Nane, yiyecek ve içecekleri tatlandırmak için kullanılabilen hızlı büyüyen bir bitkidir. Mısır, çeşitli yemeklerde kullanılabilen çok yönlü bir tahıldır. Son olarak Kale, çiğ, buharda pişirilmiş ve sotelenmiş olarak yenebilen besleyici ve çok yönlü yeşil yapraklı bir sebzedir.
#
# Top 1 Answer: Yıkılacak kadar bitkindi. (Similarity: 0.8420)
#
# Top 5 Answers:
#   1. Yıkılacak kadar bitkindi. (Similarity: 0.8420)
#   2. Bu bitkilerin yararlı olumlu etkileri vardır. (Similarity: 0.8284)
#   3. İsimler: bitki, çiçek Sıfatlar: lezzetli, akıllı (Similarity: 0.7931)
#   4. Takım durumu bekliyordu. (Similarity: 0.7923)
#   5. Sözleri kanıttan yoksundu ve bu da konuşmacıyı inandırıcı kılmıyordu. (Similarity: 0.7918)
#
# === Question 10 ===
# Instruction: Belirli bir kelimenin başka bir kelimenin anagramı olup olmadığını kontrol etmek için bir algoritma oluşturun.
# Original Answer: 1. İki kelimeyi girdi olarak alın 2. Her kelimeyi küçük harfe çevirin 3. Her kelimedeki karakterleri ayrı ayrı alfabetik olarak sıralayın 4. Sıralanan kelimeleri karşılaştırın 5. Her ikisi de aynıysa, kelimeler anagramdır Aksi takdirde kelimeler anagram değildir .
#
# Top 1 Answer: 1. İki kelimeyi girdi olarak alın 2. Her kelimeyi küçük harfe çevirin 3. Her kelimedeki karakterleri ayrı ayrı alfabetik olarak sıralayın 4. Sıralanan kelimeleri karşılaştırın 5. Her ikisi de aynıysa, kelimeler anagramdır Aksi takdirde kelimeler anagram değildir . (Similarity: 0.8308)
#
# Top 5 Answers:
#   1. 1. İki kelimeyi girdi olarak alın 2. Her kelimeyi küçük harfe çevirin 3. Her kelimedeki karakterleri ayrı ayrı alfabetik olarak sıralayın 4. Sıralanan kelimeleri karşılaştırın 5. Her ikisi de aynıysa, kelimeler anagramdır Aksi takdirde kelimeler anagram değildir . (Similarity: 0.8308)
#   2. Bir ipotek kredisi alma süreci tipik olarak bir başvuru ile başlar ve ardından mülkün değerlendirilmesi ile devam eder. Oradan, borç veren, bir kredi için iyi bir aday olup olmadığını belirlemek için borçlunun kredi puanını, istihdam geçmişini ve borç-gelir oranını gözden geçirecektir. Borçlu, borç verenin kriterlerini karşılıyorsa, kredi onaylanacak ve kapatma süreci başlayacaktır. Kapanış gününde, borçlular tüm belgeleri imzalar, kapanış masraflarını öder ve resmi olarak kredi verilir. (Similarity: 0.8253)
#   3. Sistem, metni analiz etmek ve kişisel saldırılar, tehditler ve aşağılayıcı dil gibi siber zorbalık belirtilerini tespit etmek için doğal dil işleme algoritmaları kullanmalıdır. Sistem, siber zorbalığı daha iyi tespit etmek için katılımcıların yaşı ve ilişkisi gibi bağlamsal bilgileri de dikkate almalıdır. (Similarity: 0.8249)
#   4. Bilim adamları birçok nedenden dolayı okyanusları inceler. Okyanuslar, çoğu henüz keşfedilmemiş ve belgelenmemiş binlerce bitki ve hayvan türü ile muazzam miktarda biyolojik çeşitlilik içerir. Ek olarak, okyanuslar önemli bir besin kaynağıdır ve iklim değişikliğinin etkileri hakkında fikir verebilir. Dahası, su buharının buharlaşmasını ve yoğunlaşmasını yönlendiren ve küresel hava modellerini belirlemeye yardımcı olan, Dünya'nın su döngüsünün hayati bir bileşenidirler. Son olarak, okyanuslar birçok değerli kaynağın kaynağı olarak hizmet eder ve çok çeşitli tıbbi, teknolojik ve ekonomik ilerlemeler için potansiyele sahiptir. (Similarity: 0.8247)
#   5. Bir kişinin giyim seçimi, görüşlerinin ve değerlerinin bir yansıması olabilir, çünkü giyim genellikle kendini ifade etmenin ve kendini ifade etmenin bir yolu olarak kullanılır. Örneğin, belirli giyim tarzları sosyal veya politik bir bağlantıya işaret edebilir veya bir bireyin kişisel zevklerini ve inançlarını ifade edebilir. Ek olarak, belirli kumaşlar veya desenler belirli bir kültür veya dinin göstergesi olabilir. Giyim aynı zamanda bireylerin kalabalığın arasından sıyrılmalarının ve benzersiz tarzlarını ifade etmelerinin bir yoludur. Nihayetinde, bir kişinin giyim seçimi, dünyaya onun kim olduğunu, neye inandığını ve onu neyin eşsiz kıldığını göstermenin bir yolu olabilir. (Similarity: 0.8242)
# MODEL: BGE
#
# === Question 1 ===
# Instruction: Zümrüt yeşili rengini açıklayınız.
# Original Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur.
#
# Top 1 Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.7219)
#
# Top 5 Answers:
#   1. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.7219)
#   2. Kırmızı sıcak bir renktir. (Similarity: 0.6055)
#   3. div {arka plan rengi: kırmızı; yeşil renk; } (Similarity: 0.6033)
#   4. Turuncu, sarıdan kırmızıya kadar değişen canlı ve sıcak tonlara sahip parlak bir renktir. C vitamini, enerji ve eğlence ile güçlü çağrışımları olan neşeli bir renktir. (Similarity: 0.5340)
#   5. Turuncu, güneşin teninizde yarattığı his veya taze çekilmiş portakalın suyu gibi sıcak ve canlı bir renktir. (Similarity: 0.5339)
#
# === Question 2 ===
# Instruction: Birim dönüştürme problemi için bir kopya kağıdı hazırlayın. 375 milimetreyi inç'e dönüştürün.
# Original Answer: 1 milimetre = 0,0393701 inç 375 milimetre = 14,724409448818898 inç
#
# Top 1 Answer: 1 milimetre = 0,0393701 inç 375 milimetre = 14,724409448818898 inç (Similarity: 0.6781)
#
# Top 5 Answers:
#   1. 1 milimetre = 0,0393701 inç 375 milimetre = 14,724409448818898 inç (Similarity: 0.6781)
#   2. 54 × 46 = (50 + 4) × (50 - 4) Buradan, kareler farkını kullanarak sadeleştirebiliriz: 54 × 46 = (50^2 - 4^2) = 2500 - 16 = 2484 (Similarity: 0.5467)
# ...
#   5. Bu, merkezi orijinde (0, 0) ve yarıçapı 5'e eşit olan standart bir daire denklemidir. (Similarity: 0.9166)
#
# === Question 3 ===
# Instruction: Sınavda başarısız olan birine cesaret verici bir şey söyleyin.
# Original Answer: Bazen başarısız olmak iyidir. Başarısızlık, öğrenme sürecinin bir parçasıdır. Bu deneyimi daha fazlasını öğrenmek ve bir dahaki sefere daha iyisini yapmak için bir fırsat olarak kullanabileceksiniz.
#
# Top 1 Answer: Cesareti bende bir gülümseme uyandırdı. (Similarity: 0.9574)
#
# Top 5 Answers:
#   1. Cesareti bende bir gülümseme uyandırdı. (Similarity: 0.9574)
#   2. Dik durmak, her an korkmamak, Kazanmak için her şey, ağıt için gösterecek bir şey yok. Bir cesaret ve güç şarkısı söyle, Hiç şüphe yok, sonuna kadar git. Yol bilinmese de yürü, Cesaret bulacaksın ve güçlü bir şekilde yükseleceksin. Korkularla yüzleşin, onları bir kenara itin, Rehberiniz olarak cesaretle yola devam edin. Azabın ve dehşetin üzerine çık, Göklere, cesaretin yayıldığını gör. (Similarity: 0.9506)
#   3. "Başarı nihai değildir, başarısızlık ölümcül değildir: önemli olan devam etme cesaretidir." - Winston Churchill (Similarity: 0.9307)
#   4. Jessica çocukluğuna bakıyor ve sevgiyle anıyordu. Destekleyici, cesaret verici ebeveynlerle büyüdüğü için, her zaman yeni şeyler denemesi, tutkularını keşfetmesi ve maceracı olması için teşvik edildi. Risk almaktan asla korkmadı ve denemeye cesaret edebileceğini asla düşünmediği her türlü yeni şeyi denedi. Hayat bir maceraydı, tadını çıkarmak ve keşfetmek gerekiyordu. Bildiği tek sınır, kendisine dayattığı sınırlardı. Ne zaman bir barikat belirse, basitçe bunun etrafından dolanmanın bir yolunu buluyor ya da kabul edip yoluna devam ediyordu. Sonsuz bir iyimserdi ve hayatın bizim yaptığımız şey olduğuna inandı, bu yüzden onu olağanüstü kılmak için yola çıktı. Yolculuğunun her anından keyif aldı, onlarca yeni arkadaş edindi ve çoğu insanın hayal bile edemeyeceği deneyimler yaşadı. Küçük anları - muhteşem bir gün batımı, yağmur kokusu, büyüleyici bir manzara - takdir etmek için zaman ayırdı ve sıradan güzellikte buldu. Dünya ve kendisi hakkında çok şey öğrendi ve her şeyin sonunda hayatının en güzel anlarını yaşadığını biliyordu. Hayat bir maceraydı ve o her adımını kucaklamıştı. (Similarity: 0.9276)
#   5. Bir zamanlar Kazik adında kadim ve güçlü bir ejderha varmış. Kimsenin hatırlayamadığı sürece ormanın gölgelerinde yaşamıştı. Kazık barışçıl bir yaratıktı ve evine girmeye cesaret eden insanlardan ve diğer hayvanlardan kaçınarak hayatını sürdürdü. Kazık bir gün ormanı keşfe çıkarken küçük bir köye rastlar. İnsanlar günlük yaşamlarına devam ederken hayranlıkla izledi. Becerilerinden büyülendi ve köylülere dostluğunu sunmaya karar verdi. Kazik, ormanla ilgili bilgisini, alışılmadık arazide gezinmelerine yardımcı olmak için ve ağır nesneleri taşıma gücünü kullanarak yardım teklif etti. Karşılığında köylüler ona yiyecek ve hediyeler verdiler. Zaman geçtikçe Kazık ile köylüler arasındaki dostluk güçlendi ve ünü yayılmaya başladı. Yardım istemek için dünyanın dört bir yanından insanlar geldi ve Kazık onları asla geri çevirmedi. Kazık, köyde bir demirbaş olarak kaldı ve köylülere koruma ve rehberlik sağladı. Ona ve bilgeliğine saygı duydular ve Kazık o andan itibaren sevgiyle Ormanın Bekçisi olarak tanındı. (Similarity: 0.9247)
#
# === Question 4 ===
# Instruction: Makine öğrenimi modellerindeki önyargıları anlamanın neden önemli olduğunu açıklayın.
# Original Answer: Makine öğrenimi modellerindeki önyargıları anlamak önemlidir çünkü bu önyargılar genellikle istenmeyen sonuçlara yol açabilir. Önyargı, bir model popülasyonun gerçek çeşitliliğini temsil etmeyen verilerle eğitildiğinde ortaya çıkabilir. Bu, yanlış, adaletsiz ve hatta mevcut eşitsizliği devam ettirebilecek modellerle sonuçlanabilir. Bu önyargıları anlamak, modellerin hem doğru hem de herhangi bir önyargıdan arınmış bir şekilde oluşturulmasını sağlamak için önemlidir. Bu, potansiyel önyargılar için veri setini analiz etmek, popülasyonun çeşitliliğini yakalayan üretken modelleri kullanmak ve tutarsızlıkları tespit etmek ve ele almak için adalet ölçümlerini kullanmak gibi çeşitli yaklaşımları içerebilir.
#
# Top 1 Answer: Küresel ısınma, sera gazı emisyonlarını ve ormansızlaşmayı azaltarak tersine çevrilebilir. (Similarity: 0.8945)
#
# Top 5 Answers:
#   1. Küresel ısınma, sera gazı emisyonlarını ve ormansızlaşmayı azaltarak tersine çevrilebilir. (Similarity: 0.8945)
#   2. Utanarak ayaklarını sürüdü. (Similarity: 0.8922)
#   3. Sosyal medyanın hayatımıza çok büyük etkisi oldu. (Similarity: 0.8907)
#   4. Mahkemenin kararı oybirliğiyle alındı. (Similarity: 0.8897)
#   5. Bu makine görevi gerçekleştirmek için kullanılır. (Similarity: 0.8871)
#
# === Question 5 ===
# Instruction: İyi para getiren ama tatil olmayan bir işi tanımlayın.
# Original Answer: İyi maaş veren ancak tatil olmayan bir iş, tipik olarak hava trafik kontrolörü veya anestezi uzmanı gibi uzman bir roldür. Bu tür pozisyonlar yüksek talep görmektedir ve genellikle resmi tatillerde ve hafta sonlarında çalışmayı gerektirir, bu da kişiye fazladan çalışma saatleri için ödeme yapılması anlamına gelir.
#
# Top 1 Answer: Takdir, Tanrı'nın veya doğanın manevi bir güç olarak koruyucu bakımı olarak tanımlanır. (Similarity: 0.9088)
#
# Top 5 Answers:
#   1. Takdir, Tanrı'nın veya doğanın manevi bir güç olarak koruyucu bakımı olarak tanımlanır. (Similarity: 0.9088)
#   2. Takım durumu bekliyordu. (Similarity: 0.8968)
#   3. Küresel Isınmanın Korkunç Etkileri (Similarity: 0.8955)
#   4. Bundan daha iyi bir şey görmedim. (Similarity: 0.8939)
#   5. Sorunun olası nedeni aşırı yüklenmiş bir web sunucusu veya yavaş bir internet bağlantısıdır. (Similarity: 0.8918)
#
# === Question 6 ===
# Instruction: Krep yapmak için bir tarif yazın.
# Original Answer: Malzemeler: - 1½ su bardağı çok amaçlı un - 2 yemek kaşığı şeker - 2 çay kaşığı kabartma tozu - ½ çay kaşığı kabartma tozu - ¼ çay kaşığı tuz - 1 su bardağı süt - 2 yemek kaşığı eritilmiş tereyağı - 1 büyük yumurta - 2 çay kaşığı bitkisel yağ Talimatlar: 1. Büyük bir kapta un, şeker, kabartma tozu, kabartma tozu ve tuzu birlikte çırpın. 2. Ayrı bir kapta süt, tereyağı, yumurta ve sıvı yağı çırpın. 3. Süt karışımını un karışımına dökün ve birleşene kadar karıştırın. 4. Yağlanmış bir tavayı orta-yüksek ateşte ısıtın. 5. Hamurun ¼ fincanını sıcak tavaya bırakın ve kenarlar kuruyana ve yüzeyde kabarcıklar görünene kadar pişirin. 6. Pankeki çevirin ve diğer tarafı altın rengi olana kadar yaklaşık 1-2 dakika pişirin. 7. Pankeki bir tabağa aktarın ve kalan hamurla aynı işlemi tekrarlayın. İstenilen soslarla sıcak servis yapın.
#
# Top 1 Answer: Yürüyüş, yürüyüş yapmak, doğanın tadını çıkarmak ve patikaları keşfetmekle ilişkilidir. (Similarity: 0.9308)
#
# Top 5 Answers:
#   1. Yürüyüş, yürüyüş yapmak, doğanın tadını çıkarmak ve patikaları keşfetmekle ilişkilidir. (Similarity: 0.9308)
#   2. Krep, mısır gevreği, yumurta. (Similarity: 0.9219)
#   3. Temel bir kek yapmak için gerekli malzemeler un, şeker, kakao tozu, kabartma tozu, tuz, tereyağı, yumurta ve vanilya özüdür. (Similarity: 0.9192)
#   4. Maalesef Despacito şarkısını klavyede çalamıyorum. (Similarity: 0.9167)
#   5. Milenyum Tarzını Yaşamak. (Similarity: 0.9165)
#
# === Question 7 ===
# Instruction: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi seçin
# Original Answer: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır.
#
# Top 1 Answer: Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır. (Similarity: 0.9573)
#
# Top 5 Answers:
#   1. Bir şirketin çevrimiçi verilerinin korunmasına yardımcı olabilecek üç güvenlik önlemi arasında güvenli parolalar kullanmak, iki faktörlü kimlik doğrulama kullanmak ve bir bulut güvenlik duvarı uygulamak yer alır. Verileri yetkisiz erişime karşı korumak için güvenli parolalar kullanılmalıdır. Kullanıcı kimliğini doğrulamak ve gizli bilgilere erişimi sınırlamak için iki faktörlü kimlik doğrulama kullanmak da önemlidir. Son olarak, verilerin kötü niyetli aktörler tarafından çalınmasını veya bozulmasını önlemek için bir bulut güvenlik duvarı uygulanmalıdır. (Similarity: 0.9573)
#   2. Verileri analiz ederek ve kalıpları tanımlayarak içgörüler elde edebilir ve daha bilinçli kararlar verebilirsiniz. (Similarity: 0.9290)
#   3. Nesne Yönelimli Tasarımın dört bileşeni Soyutlama, Kapsülleme, Kalıtım ve Polimorfizmdir. Soyutlama, önemli ayrıntıları vurgulayan ve ilgisiz verileri ortadan kaldıran gerçek dünyadaki bir varlığın veya sorunun bir temsilini oluşturma sürecidir. Kapsülleme, verilerin ve veriler üzerinde işlem yapan yöntemlerin tek bir birime veya nesneye paketlenmesidir. Kalıtım, sınıfların davranışı bir üst sınıftan devralmasına izin vererek kod tekrarını azaltmaya ve yeniden kullanılabilirliği geliştirmeye yardımcı olur. Polimorfizm, aynı türdeki farklı nesnelerin aynı mesaja farklı şekillerde yanıt vermesine izin verir. (Similarity: 0.9221)
#   4. Verilen veri kümesindeki kalıpları tanımlamak için Karar Ağacı gibi bir makine öğrenimi modeli oluşturun. (Similarity: 0.9216)
#   5. Müşterilere şirketle ilgili özel bir ürün koleksiyonu sunan ve kapılarına kadar teslim edilen aylık bir abonelik kutusu oluşturun. (Similarity: 0.9190)
#
# === Question 8 ===
# Instruction: Verilen son tarihe kadar bir ödevi teslim etmediğiniz için özür dilemek için bir özür mektubu oluşturun.
# Original Answer: Ödevimi belirtilen son tarihe kadar teslim edemediğim için özür dilemek için yazıyorum. Bunu yapmanın benim sorumluluğum olduğunu anlıyorum ve bu hatanın tüm sorumluluğunu kabul ediyorum. Verdiği rahatsızlıktan dolayı gerçekten üzgünüm. Aynı hatayı bir daha yapmamaya özen göstereceğim.
#
# Top 1 Answer: Verilen veri kümesindeki kalıpları tanımlamak için Karar Ağacı gibi bir makine öğrenimi modeli oluşturun. (Similarity: 0.9112)
#
# Top 5 Answers:
#   1. Verilen veri kümesindeki kalıpları tanımlamak için Karar Ağacı gibi bir makine öğrenimi modeli oluşturun. (Similarity: 0.9112)
#   2. 1. Veriler simetrik bir çan eğrisine sahiptir. 2. Ortalama, medyan ve mod eşittir. 3. Veriler tek modludur. 4. Varyans ve standart sapma sonludur. 5. Verilerin %68'i ortalamanın bir standart sapması içindedir. (Similarity: 0.9104)
#   3. Verilen doğal dil metninin duygusu olumsuz. (Similarity: 0.9103)
#   4. Ödünç alınan bir materyali iade etmek için makul bir beklenti, materyali zamanında ödünç alındığı gibi iade etmektir. Makul kabul edilen süre, borç veren ile borç alan arasındaki anlaşmaya bağlı olacaktır. Yürürlükte bir anlaşma yoksa, öğenin makul bir süre içinde, genellikle iki haftayı geçmeyecek şekilde iade edilmesi gerektiğini varsaymanız önerilir. (Similarity: 0.9102)
#   5. Kalem yazmak, çizmek, eskiz yapmak, gölgelendirmek ve keskinleştirmek için kullanılabilir. (Similarity: 0.9080)
#
# === Question 9 ===
# Instruction: En çok yönlü beş bitkiyi adlandırın.
# Original Answer: En çok yönlü beş bitki Tatlı Patates, Moringa, Nane, Mısır ve Kale'dir. Tatlı Patates, kaynatılabilen, buharda pişirilebilen veya kızartılabilen bir kök sebzedir. Moringa, taze veya kurutulmuş olarak yenebilen birçok yenilebilir parçaya sahip bir ağaçtır. Nane, yiyecek ve içecekleri tatlandırmak için kullanılabilen hızlı büyüyen bir bitkidir. Mısır, çeşitli yemeklerde kullanılabilen çok yönlü bir tahıldır. Son olarak Kale, çiğ, buharda pişirilmiş ve sotelenmiş olarak yenebilen besleyici ve çok yönlü yeşil yapraklı bir sebzedir.
#
# Top 1 Answer: Bu bitkilerin yararlı olumlu etkileri vardır. (Similarity: 0.9250)
#
# Top 5 Answers:
#   1. Bu bitkilerin yararlı olumlu etkileri vardır. (Similarity: 0.9250)
#   2. Tatile çıkacağım için çok mutluyum. (Similarity: 0.9162)
#   3. Nesli tükenmekte olan türleri avlamak yasa dışıdır. (Similarity: 0.9133)
#   4. Dün geceden beri uyumamıştı ve çok yorgundu. (Similarity: 0.9132)
#   5. Yaz günlerinde hava çok sıcak. (Similarity: 0.9084)
#
# === Question 10 ===
# Instruction: Belirli bir kelimenin başka bir kelimenin anagramı olup olmadığını kontrol etmek için bir algoritma oluşturun.
# Original Answer: 1. İki kelimeyi girdi olarak alın 2. Her kelimeyi küçük harfe çevirin 3. Her kelimedeki karakterleri ayrı ayrı alfabetik olarak sıralayın 4. Sıralanan kelimeleri karşılaştırın 5. Her ikisi de aynıysa, kelimeler anagramdır Aksi takdirde kelimeler anagram değildir .
#
# Top 1 Answer: Karar verme algoritmaları, bir bilgisayar programının karar vermek için kullandığı talimat dizileridir. Bu algoritmalar tipik olarak birden fazla kaynaktan gelen verileri kullanır ve ardından verileri işlemek için veri noktalarını önceden belirlenmiş parametrelerle karşılaştırmak veya yapay zeka veya makine öğrenimi gibi diğer karar verme tekniklerini kullanmak gibi belirli bir dizi talimat uygular. Karar verme algoritmasının çıktısı daha sonra, artan doğrulukla daha üst düzey kararlar almak için kullanılan diğer karar verme algoritmalarına girdi olarak kullanılır. Nihayetinde amaç, karar verme sürecini otomatikleştirmek ve kullanıcıya mümkün olan en iyi çözümü sağlamaktır. (Similarity: 0.9405)
#
# Top 5 Answers:
#   1. Karar verme algoritmaları, bir bilgisayar programının karar vermek için kullandığı talimat dizileridir. Bu algoritmalar tipik olarak birden fazla kaynaktan gelen verileri kullanır ve ardından verileri işlemek için veri noktalarını önceden belirlenmiş parametrelerle karşılaştırmak veya yapay zeka veya makine öğrenimi gibi diğer karar verme tekniklerini kullanmak gibi belirli bir dizi talimat uygular. Karar verme algoritmasının çıktısı daha sonra, artan doğrulukla daha üst düzey kararlar almak için kullanılan diğer karar verme algoritmalarına girdi olarak kullanılır. Nihayetinde amaç, karar verme sürecini otomatikleştirmek ve kullanıcıya mümkün olan en iyi çözümü sağlamaktır. (Similarity: 0.9405)
#   2. Geri izleme kullanılarak bir Sudoku çözme algoritması tasarlanabilir. Algoritma boş bir 9x9 ızgarayla başlar. İlk olarak, algoritma herhangi bir hücreye bir değer verilip verilmediğini kontrol eder ve eğer öyleyse, değer hücreye yerleştirilir. Bir hücreye bir değer verilmezse, algoritmanın hücreye yerleştirmek için geçerli bir sayı tanımlaması gerekir. Algoritma daha sonra hiçbir yinelenen değerin oluşmadığından emin olmak için hücreyle ilişkili satırı, sütunu ve 3*3 kutusunu kontrol edecektir. Geçerli bir sayı bulunamazsa, algoritma geri gider ve bir önceki hücre için başka bir sayı seçer ve geçerli bir çözüm bulunana kadar işlem devam eder. (Similarity: 0.9387)
#   3. Otomatik olarak seçim yapmak için bir dizi karmaşık algoritma kullanılabilir. (Similarity: 0.9374)
#   4. Bir sinir ağı, girdi verilerini istenen bir çıktıya eşlemek için tahmine dayalı bir algoritma kullanan birbirine bağlı yapay nöron katmanlarından oluşan bir makine öğrenimi modelidir. Amacı, girdi katmanından aldığı bilgilere dayalı olarak tahminler oluşturarak verilerden öğrenmek ve kalıpları tanımaktır. (Similarity: 0.9338)
#   5. Algoritma B, daha yüksek doğruluk ve daha hızlı hıza sahip olduğu için daha iyidir. (Similarity: 0.9320)

# %%
model_names = list(results.keys())
top1_scores = [results[model]['top1'] for model in model_names]
top5_scores = [results[model]['top5'] for model in model_names]

# %%
x = np.arange(len(model_names))
width = 0.4  

plt.figure(figsize=(12, 7))
fig, ax = plt.subplots()
bar1 = ax.bar(x - width/2, top1_scores, width, label='Top 1', color='skyblue')
bar2 = ax.bar(x + width/2, top5_scores, width, label='Top 5', color='green')

for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

ax.set_xlabel("Models")
ax.set_ylabel("Success Rate (%)")
ax.set_title("Model Success Rates")
ax.set_xticks(x)
ax.set_xticklabels(model_names, rotation=45)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ENSEMBLE-1: MAJORITY VOTING
#
# - For Top1: Each model's Top1 result is considered a vote. The sentence that receives the most votes is selected as the ensemble Top1. In case of a tie, the sentence with the highest similarity score is chosen.
# - For Top5: The Top5 results from all models are combined, and the sentences with the highest frequency (most votes) are selected as the ensemble Top5. In case of ties, similarity scores are used for tie-breaking.

# %%
# Evaluates the performance of an ensemble model.
# Compares the ensemble's Top-1 and Top-5 predictions with the original outputs.
# Returns success rates as percentages for Top-1 and Top-5 matches.

def evaluate_ensemble(df, ensemble_top1, ensemble_top5):
    top1_success = sum(df.iloc[i]['output'] == ensemble_top1[i] for i in range(len(df)))
    top5_success = sum(df.iloc[i]['output'] in ensemble_top5[i] for i in range(len(df)))
    
    top1_rate = (top1_success / len(df)) * 100
    top5_rate = (top5_success / len(df)) * 100
    return top1_rate, top5_rate

# %%
def voting_ensemble(models, df, output_dir, top_k=5):
    top1_votes = []
    top5_votes = []
    similarities_list_combined = []

    for model_name in models: # Collect top1 and top5 for all models
        instruction_embeddings = np.load(os.path.join(output_dir, f"{model_name}_instruction_embeddings.npy"))
        output_embeddings = np.load(os.path.join(output_dir, f"{model_name}_output_embeddings.npy"))
        top_matches, similarities_list = find_top_matches(instruction_embeddings, output_embeddings, top_k)
        top1_votes.append([df.iloc[indices[0]]['output'] for indices in top_matches])
        top5_votes.append([[df.iloc[idx]['output'] for idx in indices] for indices in top_matches])
        similarities_list_combined.append(similarities_list)

    ensemble_top1 = []     # Determine ensemble Top1
    for i in range(len(df)):
        top1_candidates = [votes[i] for votes in top1_votes]
        vote_counts = Counter(top1_candidates)
        most_common = vote_counts.most_common()
        if len(most_common) > 1 and most_common[0][1] == most_common[1][1]:
            similarities = {candidate: max(similarities_list_combined[m][i][0] for m, votes in enumerate(top1_votes) if votes[i] == candidate) for candidate, _ in most_common}
            selected = max(similarities, key=similarities.get)
        else:
            selected = most_common[0][0]
        ensemble_top1.append(selected)

    ensemble_top5 = []     # Determine ensemble Top5
    for i in range(len(df)):
        all_candidates = [output for top5 in top5_votes for output in top5[i]]
        vote_counts = Counter(all_candidates)
        top5_candidates = [output for output, _ in vote_counts.most_common(top_k)]
        ensemble_top5.append(top5_candidates)

    return ensemble_top1, ensemble_top5

# %%
ensemble_top1, ensemble_top5 = voting_ensemble(models, df, output_dir)

# %%
ensemble_top1_rate, ensemble_top5_rate = evaluate_ensemble(df, ensemble_top1, ensemble_top5)

# %%
plt.figure(figsize=(8, 5))
plt.bar(["Ensemble Top 1", "Ensemble Top 5"], [ensemble_top1_rate, ensemble_top5_rate], color=['skyblue', 'lightgreen'])
plt.ylabel("Success Rate (%)")
plt.title("Majority Voting Ensemble Success Rates")
for i, rate in enumerate([ensemble_top1_rate, ensemble_top5_rate]):
    plt.text(i, rate + 0.5, f"{rate:.2f}%", ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %%
model_names_voting_ensemble = list(results.keys())
top1_scores_voting_ensemble = [results[model]['top1'] for model in model_names]
top5_scores_voting_ensemble = [results[model]['top5'] for model in model_names]

model_names_voting_ensemble.append("MV Ensemble")
top1_scores_voting_ensemble.append(ensemble_top1_rate)
top5_scores_voting_ensemble.append(ensemble_top5_rate)

# %%
x = np.arange(len(model_names_voting_ensemble))
width = 0.4

plt.figure(figsize=(12, 7))
fig, ax = plt.subplots()
bar1 = ax.bar(x - width/2, top1_scores_voting_ensemble, width, label='Top 1', color='skyblue')
bar2 = ax.bar(x + width/2, top5_scores_voting_ensemble, width, label='Top 5', color="green")

# Add text labels on bars
for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')
for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

ax.set_xlabel("Models")
ax.set_ylabel("Success Rate (%)")
ax.set_title("Model Success Rates")
ax.set_xticks(x)
ax.set_xticklabels(model_names_voting_ensemble, rotation=45)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ENSEMBLE-2: BORDA COUNT
#
# - For Top1: Each model's Top1 result is scored based on its ranking (e.g., 1st place gets 5 points, 2nd place gets 4 points, etc.). The sentence with the highest total score across all models is selected as the ensemble Top1.
# - For Top5: Each model's Top5 results are scored using Borda Count ranking points. The scores are summed across all models, and the 5 sentences with the highest total scores are selected as the ensemble Top5.

# %%
def borda_count_ensemble(models, df, output_dir, top_k=5):
    top1_votes = []
    top5_votes = []

    for model_name in models: # Collect top1 and top5 results for all models
        instruction_embeddings = np.load(os.path.join(output_dir, f"{model_name}_instruction_embeddings.npy"))
        output_embeddings = np.load(os.path.join(output_dir, f"{model_name}_output_embeddings.npy"))
        top_matches, _ = find_top_matches(instruction_embeddings, output_embeddings, top_k)

        top1_votes.append([df.iloc[top_matches[i][0]]['output'] for i in range(len(df))])
        top5_votes.append([[df.iloc[idx]['output'] for idx in top_matches[i]] for i in range(len(df))])

    ensemble_top1 = []
    ensemble_top5 = []

    for i in range(len(df)):
        top1_candidates = Counter([votes[i] for votes in top1_votes]) # Top1 Borda Count
        ensemble_top1.append(max(top1_candidates, key=top1_candidates.get))
        
        all_top5_candidates = defaultdict(int) # Top5 Borda Count
        for model_top5 in top5_votes:
            for rank, output in enumerate(model_top5[i], 1):
                all_top5_candidates[output] += top_k - rank + 1  # Borda scoring

        sorted_top5_candidates = sorted(all_top5_candidates.items(), key=lambda x: x[1], reverse=True)
        ensemble_top5.append([output for output, _ in sorted_top5_candidates[:top_k]])

    return ensemble_top1, ensemble_top5

# %%
ensemble_top1_borda, ensemble_top5_borda = borda_count_ensemble(models, df, output_dir)

# %%
ensemble_top1_rate_borda, ensemble_top5_rate_borda = evaluate_ensemble(df, ensemble_top1_borda, ensemble_top5_borda)

# %%
plt.figure(figsize=(8, 5))
plt.bar(["Ensemble Top 1", "Ensemble Top 5"], [ensemble_top1_rate_borda, ensemble_top5_rate_borda], color=['skyblue', 'lightgreen'])
plt.ylabel("Success Rate (%)")
plt.title("Borda Count Ensemble Success Rates")
for i, rate in enumerate([ensemble_top1_rate_borda, ensemble_top5_rate_borda]):
    plt.text(i, rate + 0.5, f"{rate:.2f}%", ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %%
model_names_borda_ensemble = list(results.keys())
top1_scores_borda_ensemble = [results[model]['top1'] for model in model_names]
top5_scores_borda_ensemble = [results[model]['top5'] for model in model_names]

model_names_borda_ensemble.append("BC Ensemble")
top1_scores_borda_ensemble.append(ensemble_top1_rate_borda)
top5_scores_borda_ensemble.append(ensemble_top5_rate_borda)

# %%
x = np.arange(len(model_names_borda_ensemble))
width = 0.4

plt.figure(figsize=(12, 7))
fig, ax = plt.subplots()
bar1 = ax.bar(x - width/2, top1_scores_borda_ensemble, width, label='Top 1', color='skyblue')
bar2 = ax.bar(x + width/2, top5_scores_borda_ensemble, width, label='Top 5', color="green")

for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')
for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

ax.set_xlabel("Models")
ax.set_ylabel("Success Rate (%)")
ax.set_title("Model Success Rates")
ax.set_xticks(x)
ax.set_xticklabels(model_names_borda_ensemble, rotation=45)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ENSEMBLE-3: MEAN
#
# - For Top1: Averages the Top1 scores of each model and selects the sentence with the highest average score.
# - For Top5: Combines the sentences in the Top5 results of the models and averages the scores for the same sentences. The 5 sentences with the highest average score are selected.

# %%
def mean_ensemble(models, df, output_dir, top_k=5):
    top1_scores = []
    top5_scores = []

    for model_name in models: # Collect top1 and top5 results with scores for all models
        instruction_embeddings = np.load(os.path.join(output_dir, f"{model_name}_instruction_embeddings.npy"))
        output_embeddings = np.load(os.path.join(output_dir, f"{model_name}_output_embeddings.npy"))
        top_matches, similarities_list = find_top_matches(instruction_embeddings, output_embeddings, top_k)
        top1_scores.append([(df.iloc[indices[0]]['output'], similarities[0]) for indices, similarities in zip(top_matches, similarities_list)])
        top5_scores.append([[(df.iloc[idx]['output'], similarities[j]) for j, idx in enumerate(indices)] for indices, similarities in zip(top_matches, similarities_list)])

    ensemble_top1 = [] # Determine ensemble Top1
    for i in range(len(df)):
        all_top1 = defaultdict(list)
        for model_top1 in top1_scores:
            output, score = model_top1[i]
            all_top1[output].append(score)
        mean_scores = {output: np.mean(scores) for output, scores in all_top1.items()}
        selected = max(mean_scores, key=mean_scores.get)
        ensemble_top1.append(selected)
    
    ensemble_top5 = [] # Determine ensemble Top5
    for i in range(len(df)):
        all_top5 = defaultdict(list)
        for model_top5 in top5_scores:
            for output, score in model_top5[i]:
                all_top5[output].append(score)
        mean_scores = {output: np.mean(scores) for output, scores in all_top5.items()}
        sorted_top5 = sorted(mean_scores.items(), key=lambda x: x[1], reverse=True)
        top5_candidates = [output for output, _ in sorted_top5[:top_k]]
        ensemble_top5.append(top5_candidates)

    return ensemble_top1, ensemble_top5

# %%
ensemble_top1_mean, ensemble_top5_mean = mean_ensemble(models, df, output_dir)

# %%
ensemble_top1_rate_mean, ensemble_top5_rate_mean = evaluate_ensemble(df, ensemble_top1_mean, ensemble_top5_mean)

# %%
plt.figure(figsize=(8, 5))
plt.bar(["Ensemble Top 1", "Ensemble Top 5"], [ensemble_top1_rate_mean, ensemble_top5_rate_mean], color=['skyblue', 'lightgreen'])
plt.ylabel("Success Rate (%)")
plt.title("Mean Ensemble Success Rates")
for i, rate in enumerate([ensemble_top1_rate_mean, ensemble_top5_rate_mean]):
    plt.text(i, rate + 0.5, f"{rate:.2f}%", ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %%
model_names_mean_ensemble = list(results.keys())
top1_scores_mean_ensemble = [results[model]['top1'] for model in model_names]
top5_scores_mean_ensemble = [results[model]['top5'] for model in model_names]

model_names_mean_ensemble.append("M Ensemble")
top1_scores_mean_ensemble.append(ensemble_top1_rate_mean)
top5_scores_mean_ensemble.append(ensemble_top5_rate_mean)

# %%
ensemble_top5_rate_mean
# Out:
# 12.9

# %%
x = np.arange(len(model_names_mean_ensemble))
width = 0.4

plt.figure(figsize=(12, 7))
fig, ax = plt.subplots()
bar1 = ax.bar(x - width/2, top1_scores_mean_ensemble, width, label='Top 1 Success Rate', color= "skyblue")
bar2 = ax.bar(x + width/2, top5_scores_mean_ensemble, width, label='Top 5 Success Rate', color="green")

# Add text labels on bars
for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')
for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

ax.set_xlabel("Models")
ax.set_ylabel("Success Rate (%)")
ax.set_title("Model Success Rates")
ax.set_xticks(x)
ax.set_xticklabels(model_names_mean_ensemble, rotation=45)
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# 12.9

# %%
ensemble_methods = ["Voting Ensemble", "Borda Count Ensemble", "Mean Ensemble"]
ensemble_top1_rates = [ensemble_top1_rate, ensemble_top1_rate_borda, ensemble_top1_rate_mean]
ensemble_top5_rates = [ensemble_top5_rate, ensemble_top5_rate_borda, ensemble_top5_rate_mean]

x = np.arange(len(ensemble_methods))
width = 0.35

plt.figure(figsize=(12, 7))
fig, ax = plt.subplots()
bar1 = ax.bar(x - width/2, ensemble_top1_rates, width, label='Top 1', color='skyblue')
bar2 = ax.bar(x + width/2, ensemble_top5_rates, width, label='Top 5', color='lightgreen')

for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')
for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

ax.set_xlabel("Ensemble Methods")
ax.set_ylabel("Success Rate (%)")
ax.set_title("Ensemble Method Comparison")
ax.set_xticks(x)
ax.set_xticklabels(ensemble_methods, rotation=45)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## EXAMPLE

# %%
def get_results_for_first_instruction(models, df, output_dir, top_k=5):
    first_instruction = df.iloc[0]['instruction']
    original_output = df.iloc[0]['output']

    print(f"\n=== First Instruction ===")
    print(f"Instruction: {first_instruction}")
    print(f"Original Answer: {original_output}\n")

    for model_name in models:
        instruction_embeddings = np.load(os.path.join(output_dir, f"{model_name}_instruction_embeddings.npy"))
        output_embeddings = np.load(os.path.join(output_dir, f"{model_name}_output_embeddings.npy"))
        top_matches, similarities_list = find_top_matches(instruction_embeddings, output_embeddings, top_k)

        top1_output = df.iloc[top_matches[0][0]]['output']
        top5_outputs = [df.iloc[idx]['output'] for idx in top_matches[0]]

        print(f"Model: {model_name}")
        print(f"Top 1 Answer: {top1_output} (Similarity: {similarities_list[0][0]:.4f})")
        print("Top 5 Answers:")
        for rank, (output, similarity) in enumerate(zip(top5_outputs, similarities_list[0]), 1):
            print(f"  {rank}. {output} (Similarity: {similarity:.4f})")
        print()

    ensemble_top1_voting, ensemble_top5_voting = voting_ensemble(models, df, output_dir, top_k)
    ensemble_top1_max, ensemble_top5_max = borda_count_ensemble(models, df, output_dir, top_k)
    ensemble_top1_mean, ensemble_top5_mean = mean_ensemble(models, df, output_dir, top_k)

    print("Voting Ensemble Results:")
    print(f"Top 1 Answer: {ensemble_top1_voting[0]}")
    print("Top 5 Answers:")
    for rank, answer in enumerate(ensemble_top5_voting[0], 1):
        print(f"  {rank}. {answer}")
    print()

    print("Borda Count Ensemble Results:")
    print(f"Top 1 Answer: {ensemble_top1_max[0]}")
    print("Top 5 Answers:")
    for rank, answer in enumerate(ensemble_top5_max[0], 1):
        print(f"  {rank}. {answer}")
    print()

    print("Mean Ensemble Results:")
    print(f"Top 1 Answer: {ensemble_top1_mean[0]}")
    print("Top 5 Answers:")
    for rank, answer in enumerate(ensemble_top5_mean[0], 1):
        print(f"  {rank}. {answer}")


get_results_for_first_instruction(models, df, output_dir)
# Out:
# === First Instruction ===
# Instruction: Zümrüt yeşili rengini açıklayınız.
# Original Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur.
#
# Model: cosmos-colbert
# Top 1 Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.9284)
# Top 5 Answers:
#   1. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.9284)
#   2. Kırmızı sıcak bir renktir. (Similarity: 0.9271)
#   3. Kırmızı ve Mavi'nin her ikisi de ana renklerdir, ancak Kırmızı çok daha parlaktır ve bir sıcaklığı vardır, Mavi ise daha soğuk ve sakindir. Sarı, tipik olarak neşeyle ilişkilendirilen ikincil bir renktir, Kırmızı ve Mavi ise genellikle daha yoğun olarak görülür. (Similarity: 0.9201)
#   4. Turuncu, sarıdan kırmızıya kadar değişen canlı ve sıcak tonlara sahip parlak bir renktir. C vitamini, enerji ve eğlence ile güçlü çağrışımları olan neşeli bir renktir. (Similarity: 0.9094)
#   5. Aurora'nın renkleri, güneşten salınan elektrik yüklü parçacıklar ile Dünya atmosferindeki gazlar arasındaki çarpışmalardan kaynaklanır. Bu parçacıklar atmosfere girerek farklı yüksekliklerde oksijen ve nitrojen atomları ile çarpışırlar. Bu çarpışmalar, kutup ışıklarında görülen kırmızı, yeşil ve mavi renkleri veren ışık parçacıkları olan fotonların salınmasına yol açar. Renkler, vurulan gazın türüne ve yüksekliğine bağlıdır. (Similarity: 0.9035)
#
# Model: minilm
# Top 1 Answer: Nisan ayında meydana gelen yağışlar, Mayıs ayında rengarenk çiçek açacaktır. (Similarity: 0.8623)
# Top 5 Answers:
#   1. Nisan ayında meydana gelen yağışlar, Mayıs ayında rengarenk çiçek açacaktır. (Similarity: 0.8623)
#   2. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.8205)
#   3. Yazıyorum. (Similarity: 0.8160)
#   4. Tasarımın iki unsuru denge ve renktir. (Similarity: 0.8140)
#   5. Mutlulukla en çok ilişkilendirilen renkler parlak maviler, sarılar, turuncular ve yeşillerdir. Bu renkler umut, enerji ve iyimserlik duygularını çağrıştırır. Bir kişinin ruh hali üzerinde olumlu etkileri olabileceğinden, genellikle perakende mağazaları ve restoranlar gibi ortamlarda kullanılırlar. (Similarity: 0.8084)
#
# Model: bge
# Top 1 Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.7219)
# Top 5 Answers:
#   1. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.7219)
#   2. Kırmızı sıcak bir renktir. (Similarity: 0.6055)
#   3. div {arka plan rengi: kırmızı; yeşil renk; } (Similarity: 0.6033)
#   4. Turuncu, sarıdan kırmızıya kadar değişen canlı ve sıcak tonlara sahip parlak bir renktir. C vitamini, enerji ve eğlence ile güçlü çağrışımları olan neşeli bir renktir. (Similarity: 0.5340)
#   5. Turuncu, güneşin teninizde yarattığı his veya taze çekilmiş portakalın suyu gibi sıcak ve canlı bir renktir. (Similarity: 0.5339)
#
# Model: jina
# Top 1 Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.9186)
# Top 5 Answers:
#   1. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur. (Similarity: 0.9186)
#   2. Kırmızı sıcak bir renktir. (Similarity: 0.6298)
#   3. Lezzetli bir yeşil salata için alışveriş listesi: - 5-6 su bardağı yeşil salata (ıspanak, marul veya diğer yapraklı yeşillikler) - 2 su bardağı doğranmış sebze (domates, salatalık, havuç, biber) - 1/4 su bardağı ufalanmış beyaz peynir - 1/4 bardak dilimlenmiş zeytin - 2 yemek kaşığı zeytinyağı - 2 yemek kaşığı balzamik sirke - 1/4 çay kaşığı tuz ve karabiber - İsteğe bağlı: ilave protein için kızarmış ekmek veya pişmiş tavuk. (Similarity: 0.6110)
#   4. mavi şemsiye (Similarity: 0.6084)
#   5. Müşteri pembe ve yeşil çizgili resmi elbise pantolonu ve açık mavi chambray gömlek ile başlamalıdır. Açık mavi chambray gömlek, bastırılmış bir ton olduğu için pantolonla rekabet etmese de cesur çizgilere karşı kontrast sağlayacaktır. Odanın inceliği, müşterinin bitmiş bir görünüm için parlak yeşil veya pembe ifadeli kolye veya eşarplar gibi daha cesur aksesuarlar eklemesine izin verecektir. (Similarity: 0.5983)
#
# Model: gte
# Top 1 Answer: Utanarak ayaklarını sürüdü. (Similarity: 0.9122)
# Top 5 Answers:
#   1. Utanarak ayaklarını sürüdü. (Similarity: 0.9122)
#   2. Kız kardeşim ve ben kıyafet alışverişi yapıyoruz. (Similarity: 0.8987)
#   3. Mahkemenin kararı oybirliğiyle alındı. (Similarity: 0.8973)
#   4. Sağlıklı bir günlük meyve ve sebze porsiyonu yemek, hastalıkları önlemeye yardımcı olabilir. (Similarity: 0.8964)
#   5. Kedi çitin üzerinde yüksek sesle miyavladı. (Similarity: 0.8953)
#
# Voting Ensemble Results:
# Top 1 Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur.
# Top 5 Answers:
#   1. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur.
#   2. Kırmızı sıcak bir renktir.
#   3. Turuncu, sarıdan kırmızıya kadar değişen canlı ve sıcak tonlara sahip parlak bir renktir. C vitamini, enerji ve eğlence ile güçlü çağrışımları olan neşeli bir renktir.
#   4. Kırmızı ve Mavi'nin her ikisi de ana renklerdir, ancak Kırmızı çok daha parlaktır ve bir sıcaklığı vardır, Mavi ise daha soğuk ve sakindir. Sarı, tipik olarak neşeyle ilişkilendirilen ikincil bir renktir, Kırmızı ve Mavi ise genellikle daha yoğun olarak görülür.
#   5. Aurora'nın renkleri, güneşten salınan elektrik yüklü parçacıklar ile Dünya atmosferindeki gazlar arasındaki çarpışmalardan kaynaklanır. Bu parçacıklar atmosfere girerek farklı yüksekliklerde oksijen ve nitrojen atomları ile çarpışırlar. Bu çarpışmalar, kutup ışıklarında görülen kırmızı, yeşil ve mavi renkleri veren ışık parçacıkları olan fotonların salınmasına yol açar. Renkler, vurulan gazın türüne ve yüksekliğine bağlıdır.
#
# Borda Count Ensemble Results:
# Top 1 Answer: Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur.
# Top 5 Answers:
#   1. Zümrüt yeşili, uçuk yeşilden koyu yeşime kadar değişen canlı ve parlak bir renk tonudur. Taşın rengini yansıtan mücevher benzeri bir kaliteye sahiptir. Zümrüt yeşili, yaşam ve enerji dolu, gür, şiirsel olarak derin bir gölge olarak tanımlanabilir. Resimde, ağaçların, çimenlerin ve yaprakların dış mekan sahnelerini yakalamak için mükemmel renk tonudur.
#   2. Kırmızı sıcak bir renktir.
#   3. Nisan ayında meydana gelen yağışlar, Mayıs ayında rengarenk çiçek açacaktır.
#   4. Utanarak ayaklarını sürüdü.
#   5. Turuncu, sarıdan kırmızıya kadar değişen canlı ve sıcak tonlara sahip parlak bir renktir. C vitamini, enerji ve eğlence ile güçlü çağrışımları olan neşeli bir renktir.
#
# Mean Ensemble Results:
# Top 1 Answer: Utanarak ayaklarını sürüdü.
# Top 5 Answers:
#   1. Kırmızı ve Mavi'nin her ikisi de ana renklerdir, ancak Kırmızı çok daha parlaktır ve bir sıcaklığı vardır, Mavi ise daha soğuk ve sakindir. Sarı, tipik olarak neşeyle ilişkilendirilen ikincil bir renktir, Kırmızı ve Mavi ise genellikle daha yoğun olarak görülür.
#   2. Utanarak ayaklarını sürüdü.
#   3. Aurora'nın renkleri, güneşten salınan elektrik yüklü parçacıklar ile Dünya atmosferindeki gazlar arasındaki çarpışmalardan kaynaklanır. Bu parçacıklar atmosfere girerek farklı yüksekliklerde oksijen ve nitrojen atomları ile çarpışırlar. Bu çarpışmalar, kutup ışıklarında görülen kırmızı, yeşil ve mavi renkleri veren ışık parçacıkları olan fotonların salınmasına yol açar. Renkler, vurulan gazın türüne ve yüksekliğine bağlıdır.
#   4. Kız kardeşim ve ben kıyafet alışverişi yapıyoruz.
#   5. Mahkemenin kararı oybirliğiyle alındı.
